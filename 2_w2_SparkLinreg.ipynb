# %%
import ibmos2spark
# @hidden_cell
credentials = {
    'endpoint': 'https://s3-api.us-geo.objectstorage.service.networklayer.com',
    'service_id': 'iam-ServiceId-edcac660-5945-4055-884a-69a7d90eb77d',
    'iam_service_endpoint': 'https://iam.ng.bluemix.net/oidc/token',
    'api_key': 'B5ImjlYR3tO0UklwhGHi3Il8kBVSPsJqB1-Su_pnYGri'
}

configuration_name = 'os_c46d077b027a44afb17b45592db82132_configs'
cos = ibmos2spark.CloudObjectStorage(sc, credentials, configuration_name, 'bluemix_cos')

from pyspark.sql import SparkSession
spark = SparkSession.builder.getOrCreate()
df_data_1 = spark.read\
  .format('org.apache.spark.sql.execution.datasources.csv.CSVFileFormat')\
  .option('header', 'true')\
  .load(cos.url('floorsensordata2604.csv', 'default-donotdelete-pr-ffcm1w3pd7kehf'))
df_data_1.take(5)
# Out:
# Waiting for a Spark session to start...
# Spark Initialization Done! ApplicationId = app-20191010104512-0000
# KERNEL_ID = 09ef96df-27e3-402d-b400-6281d1ed4375
# [Row(_c0='0', itemname='52760_5_temperature_value', sensorname='item0001', time='2018-02-19T07:05:00.165Z', value='20.5'),
#  Row(_c0='1', itemname='47406_3_temperature_value', sensorname='item0002', time='2018-02-19T07:05:00.240Z', value='20.61'),
#  Row(_c0='2', itemname='452B5_3_temperature_value', sensorname='item0003', time='2018-02-19T07:05:00.316Z', value='19.89'),
#  Row(_c0='3', itemname='452F9_3_temperature_value', sensorname='item0004', time='2018-02-19T07:05:00.388Z', value='19.7'),
#  Row(_c0='4', itemname='4521C_3_temperature_value', sensorname='item0005', time='2018-02-19T07:05:00.460Z', value='18.89')]

# %%
df_data_1.show()
df = df_data_1
# Out:
# +---+--------------------+----------+--------------------+------+
# |_c0|            itemname|sensorname|                time| value|
# +---+--------------------+----------+--------------------+------+
# |  0|52760_5_temperatu...|  item0001|2018-02-19T07:05:...|  20.5|
# |  1|47406_3_temperatu...|  item0002|2018-02-19T07:05:...| 20.61|
# |  2|452B5_3_temperatu...|  item0003|2018-02-19T07:05:...| 19.89|
# |  3|452F9_3_temperatu...|  item0004|2018-02-19T07:05:...|  19.7|
# |  4|4521C_3_temperatu...|  item0005|2018-02-19T07:05:...| 18.89|
# |  5|51A51_5_temperatu...|  item0006|2018-02-19T07:05:...|21.812|
# |  6|512F5_5_temperatu...|  item0007|2018-02-19T07:05:...|    21|
# |  7|45974_3_temperatu...|  item0008|2018-02-19T07:05:...| 21.06|
# |  8|52686_5_temperatu...|  item0009|2018-02-19T07:05:...|    21|
# |  9|45152_3_temperatu...|  item0010|2018-02-19T07:05:...|  20.2|
# | 10|51BEB_5_temperatu...|  item0011|2018-02-19T07:05:...|    21|
# ...

# %%
df.createOrReplaceTempView('df')
