# %% [markdown]
# this notebook is a reuse of kernel feature-engineering-xgboost
#
# #### Pipline, XGBOOST and LSTM model
# * load data
# * heal data and remove outliers
# * work with shops/items/cats objects and features
# * create matrix as product of item/shop pairs within each month in the train set
# * get monthly sales for each item/shop pair in the train set and merge it to the matrix
# * clip item_cnt_month by (0,20)
# * append test to the matrix, fill 34 month nans with zeros
# * merge shops/items/cats to the matrix
# * add target lag features
# * add mean encoded features
# * add price trend features
# * add month
# * add days
# * add months since last sale/months since first sale features
# * cut first year and drop columns which can not be calculated for the test set
# * select best features
# * set validation strategy 33 train/validation, test 34
# * fit the xgboost model, predict and clip targets for the test set
# * fit the LSTM model, predict and clip targets for the test set
# * combine both model

# %% [markdown]
# # Part 1, perfect features

# %%
import os
from datetime import datetime
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"


import numpy as np
import pandas as pd
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 100)

from itertools import product
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split

import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

from xgboost import XGBRegressor
from xgboost import plot_importance

from keras.models import Sequential
from keras.layers import LSTM, Dense, Dropout
from sklearn.metrics import mean_squared_error

import time
def plot_features(booster, figsize):    
    fig, ax = plt.subplots(1,1,figsize=figsize)
    return plot_importance(booster=booster, ax=ax)

import time
import sys
import gc
import pickle
sys.version_info
# Out:
# Using TensorFlow backend.
# sys.version_info(major=3, minor=7, micro=3, releaselevel='final', serial=0)

# %%
# importing required modules 
from zipfile import ZipFile 

# specifying the zip file name 
file_name = "competitive-data-science-predict-future-sales.zip"

# opening the zip file in READ mode 
with ZipFile(file_name, 'r') as zip: 
    # printing all the contents of the zip file 
    zip.printdir() 

    # extracting all the files 
    print('Extracting all the files now...') 
    zip.extractall() 
    print('Done!') 
    print('Credits to Geeks for Geeks - https://www.geeksforgeeks.org/working-zip-files-python/')
# Out:
# File Name                                             Modified             Size
# item_categories.csv                            2019-12-15 22:01:26         3573
# items.csv                                      2019-12-15 22:01:26      1568417
# sales_train.csv                                2019-12-15 22:01:28     94603866
# sample_submission.csv                          2019-12-15 22:01:34      2245108
# shops.csv                                      2019-12-15 22:01:34         2977
# test.csv                                       2019-12-15 22:01:34      3182735
# Extracting all the files now...
# Done!
# Credits to Geeks for Geeks - https://www.geeksforgeeks.org/working-zip-files-python/

# %%
# load unzipped csv files
CurrentPath = os.getcwd()
startTime = datetime.now()

test = pd.read_csv(CurrentPath+'/test.csv'
                    , dtype={'ID': 'int32', 'shop_id': 'int32', 'item_id': 'int32'})
print('test loaded in '+str(datetime.now() - startTime))
startTime = datetime.now()
item_categories = pd.read_csv(CurrentPath+'/item_categories.csv'
                    , dtype={'item_category_name': 'str', 'item_category_id': 'int32'})
print('item_categories loaded in '+str(datetime.now() - startTime))
startTime = datetime.now()
items = pd.read_csv(CurrentPath+'/items.csv'
                    , dtype={'item_name': 'str', 'item_id': 'int32', 'item_category_id': 'int32'})
print('items loaded in '+str(datetime.now() - startTime))
startTime = datetime.now()
shops = pd.read_csv(CurrentPath+'/shops.csv'
                    , dtype={'shop_name': 'str', 'shop_id': 'int32'})
print('shops loaded in '+str(datetime.now() - startTime))
startTime = datetime.now()
sales_train = pd.read_csv(CurrentPath+'/sales_train.csv'
                    , dtype={'date': 'str', 'date_block_num': 'int32', 'shop_id': 'int32', 
                          'item_id': 'int32', 'item_price': 'float32', 'item_cnt_day': 'int32'})
print('sales_train loaded in '+str(datetime.now() - startTime))
# Out:
# test loaded in 0:00:00.070432
# item_categories loaded in 0:00:00.002782
# items loaded in 0:00:00.028490
# shops loaded in 0:00:00.002540
# sales_train loaded in 0:00:01.093651

# %%
#items = pd.read_csv('../input/items.csv')
#shops = pd.read_csv('../input/shops.csv')
cats = item_categories
train = sales_train
# set index to ID to avoid droping it later
#test  = pd.read_csv('../input/test.csv').set_index('ID')

# %% [markdown]
# ## Outliers

# %% [markdown]
# There are items with strange prices and sales. After detailed exploration I decided to remove items with price > 100000 and sales > 1001 (1000 is ok).

# %%
plt.figure(figsize=(10,4))
plt.xlim(-100, 3000)
sns.boxplot(x=train.item_cnt_day)

plt.figure(figsize=(10,4))
plt.xlim(train.item_price.min(), train.item_price.max()*1.1)
sns.boxplot(x=train.item_price)
# Out:
# (-100, 3000)
# (-1.0, 338778.0)

# %%
train = train[train.item_price<100000]
train = train[train.item_cnt_day<1001]

# %% [markdown]
# There is one item with price below zero. Fill it with median.

# %%
median = train[(train.shop_id==32)&(train.item_id==2973)&(train.date_block_num==4)&(train.item_price>0)].item_price.median()
train.loc[train.item_price<0, 'item_price'] = median

# %% [markdown]
# Several shops are duplicates of each other (according to its name). Fix train and test set.

# %%
# Якутск Орджоникидзе, 56
train.loc[train.shop_id == 0, 'shop_id'] = 57
test.loc[test.shop_id == 0, 'shop_id'] = 57
# Якутск ТЦ "Центральный"
train.loc[train.shop_id == 1, 'shop_id'] = 58
test.loc[test.shop_id == 1, 'shop_id'] = 58
# Жуковский ул. Чкалова 39м²
train.loc[train.shop_id == 10, 'shop_id'] = 11
test.loc[test.shop_id == 10, 'shop_id'] = 11

# %% [markdown]
# ## Shops/Cats/Items preprocessing
# Observations:
# * Each shop_name starts with the city name.
# * Each category contains type and subtype in its name.

# %%
# before
shops.head(2)
cats.head(2)
# Out:
#                        shop_name  shop_id
# 0  !Якутск Орджоникидзе, 56 фран        0
# 1  !Якутск ТЦ "Центральный" фран        1
#         item_category_name  item_category_id
# 0  PC - Гарнитуры/Наушники                 0
# 1         Аксессуары - PS2                 1

# %%
shops.loc[shops.shop_name == 'Сергиев Посад ТЦ "7Я"', 'shop_name'] = 'СергиевПосад ТЦ "7Я"'
shops['city'] = shops['shop_name'].str.split(' ').map(lambda x: x[0])
#remove exclmation points in some city names
shops.loc[shops.city == '!Якутск', 'city'] = 'Якутск'
shops['city_code'] = LabelEncoder().fit_transform(shops['city'])
shops = shops[['shop_id','city_code']]

cats['split'] = cats['item_category_name'].str.split('-')
cats['type'] = cats['split'].map(lambda x: x[0].strip())
cats['type_code'] = LabelEncoder().fit_transform(cats['type'])
# if subtype is nan then type
cats['subtype'] = cats['split'].map(lambda x: x[1].strip() if len(x) > 1 else x[0].strip())
cats['subtype_code'] = LabelEncoder().fit_transform(cats['subtype'])
cats = cats[['item_category_id','type_code', 'subtype_code']]

items.drop(['item_name'], axis=1, inplace=True)

# %%
#after
shops.head(2)
cats.head(2)
# Out:
#    shop_id  city_code
# 0        0         29
# 1        1         29
#    item_category_id  type_code  subtype_code
# 0                 0          0            29
# 1                 1          1             9

# %% [markdown]
# ## Monthly sales
# Test set is a product of some shops and some items within 34 month. There are 5100 items * 42 shops = 214200 pairs. 363 items are new compared to the train. Hence, for the most of the items in the test set target value should be zero.
# In the other hand train set contains only pairs which were sold or returned in the past. Tha main idea is to calculate monthly sales and <b>extend it with zero sales</b> for each unique pair within the month. This way train data will be similar to test data.

# %%
len(list(set(test.item_id) - set(test.item_id).intersection(set(train.item_id)))), len(list(set(test.item_id))), len(test)
# Out:
# (363, 5100, 214200)

# %%
ts = time.time()
#create an empty dataframe
matrix = []
cols = ['date_block_num','shop_id','item_id']
for i in range(34):
    sales = train[train.date_block_num==i]
    matrix.append(np.array(list(product([i], sales.shop_id.unique(), sales.item_id.unique())), dtype='int16'))
    
#Stack arrays in sequence vertically (row wise).
matrix = pd.DataFrame(np.vstack(matrix), columns=cols)
#change data type
matrix['date_block_num'] = matrix['date_block_num'].astype(np.int8)
matrix['shop_id'] = matrix['shop_id'].astype(np.int8)
matrix['item_id'] = matrix['item_id'].astype(np.int16)
#sort
matrix.sort_values(cols,inplace=True)
#time lapsed
time.time() - ts
# Out:
# 9.752489805221558

# %%
matrix.shape
matrix.tail()
# Out:
# (10913804, 3)
#           date_block_num  shop_id  item_id
# 10768788              33       59    22162
# 10768978              33       59    22163
# 10769644              33       59    22164
# 10771170              33       59    22166
# 10770465              33       59    22167

# %% [markdown]
# Aggregate train set by shop/item pairs to calculate target aggreagates, then <b>clip(0,20)</b> target value. This way train target will be similar to the test predictions.
#
# <i>I use floats instead of ints for item_cnt_month to avoid downcasting it after concatination with the test set later. If it would be int16, after concatination with NaN values it becomes int64, but foat16 becomes float16 even with NaNs.</i>

# %%
train.head()
# Out:
#          date  date_block_num  shop_id  item_id   item_price  item_cnt_day
# 0  02.01.2013               0       59    22154   999.000000             1
# 1  03.01.2013               0       25     2552   899.000000             1
# 2  05.01.2013               0       25     2552   899.000000            -1
# 3  06.01.2013               0       25     2554  1709.050049             1
# 4  15.01.2013               0       25     2555  1099.000000             1

# %%
train['revenue'] = train['item_price'] *  train['item_cnt_day']

# %%
train.head()
# Out:
#          date  date_block_num  shop_id  item_id   item_price  item_cnt_day  \
# 0  02.01.2013               0       59    22154   999.000000             1
# 1  03.01.2013               0       25     2552   899.000000             1
# 2  05.01.2013               0       25     2552   899.000000            -1
# 3  06.01.2013               0       25     2554  1709.050049             1
# 4  15.01.2013               0       25     2555  1099.000000             1
#
#        revenue
# 0   999.000000
# 1   899.000000
# 2  -899.000000
# 3  1709.050049
# 4  1099.000000

# %%
ts = time.time()
group = train.groupby(['date_block_num','shop_id','item_id']).agg({'item_cnt_day': ['sum']})
group.columns = ['item_cnt_month']
group.reset_index(inplace=True)

matrix = pd.merge(matrix, group, on=cols, how='left')
matrix['item_cnt_month'] = (matrix['item_cnt_month']
                                .fillna(0)
                                .clip(0,20) # NB clip target here Given an interval, values outside the interval are clipped to the interval edges. For example, if an interval of [0, 1] is specified, values smaller than 0 become 0, and values larger than 1 become 1.
                                .astype(np.float16))
time.time() - ts
# Out:
# 4.5297558307647705

# %%
matrix.shape
matrix.tail()
# Out:
# (10913804, 4)
#           date_block_num  shop_id  item_id  item_cnt_month
# 10913799              33       59    22162             0.0
# 10913800              33       59    22163             0.0
# 10913801              33       59    22164             0.0
# 10913802              33       59    22166             0.0
# 10913803              33       59    22167             0.0

# %% [markdown]
# ## Test set
# To use time tricks append test pairs to the matrix.

# %%
test.head()
# Out:
#    ID  shop_id  item_id
# 0   0        5     5037
# 1   1        5     5320
# 2   2        5     5233
# 3   3        5     5232
# 4   4        5     5268

# %%
test['date_block_num'] = 34
test['date_block_num'] = test['date_block_num'].astype(np.int8)
test['shop_id'] = test['shop_id'].astype(np.int8)
test['item_id'] = test['item_id'].astype(np.int16)

# %%
ts = time.time()
# concat with the matrix
matrix = pd.concat([matrix, test], ignore_index=True, sort=False, keys=cols)
matrix.fillna(0, inplace=True) # 34 month
time.time() - ts
# Out:
# 0.1508488655090332

# %%
test.head()
matrix.shape
matrix.tail()
# Out:
#    ID  shop_id  item_id  date_block_num
# 0   0        5     5037              34
# 1   1        5     5320              34
# 2   2        5     5233              34
# 3   3        5     5232              34
# 4   4        5     5268              34
# (11128004, 5)
#           date_block_num  shop_id  item_id  item_cnt_month        ID
# 11127999              34       45    18454             0.0  214195.0
# 11128000              34       45    16188             0.0  214196.0
# 11128001              34       45    15757             0.0  214197.0
# 11128002              34       45    19648             0.0  214198.0
# 11128003              34       45      969             0.0  214199.0

# %% [markdown]
# ## Shops/Items/Cats features

# %%
matrix.shape
matrix.tail()
# Out:
# (11128004, 5)
#           date_block_num  shop_id  item_id  item_cnt_month        ID
# 11127999              34       45    18454             0.0  214195.0
# 11128000              34       45    16188             0.0  214196.0
# 11128001              34       45    15757             0.0  214197.0
# 11128002              34       45    19648             0.0  214198.0
# 11128003              34       45      969             0.0  214199.0

# %%
ts = time.time()
#merge all
matrix = pd.merge(matrix, shops, on=['shop_id'], how='left')
matrix = pd.merge(matrix, items, on=['item_id'], how='left')
matrix = pd.merge(matrix, cats, on=['item_category_id'], how='left')
matrix['city_code'] = matrix['city_code'].astype(np.int8)
matrix['item_category_id'] = matrix['item_category_id'].astype(np.int8)
matrix['type_code'] = matrix['type_code'].astype(np.int8)
matrix['subtype_code'] = matrix['subtype_code'].astype(np.int8)
time.time() - ts
# Out:
# 3.415332794189453

# %%
matrix.shape
matrix.tail()
# Out:
# (11128004, 9)
#           date_block_num  shop_id  item_id  item_cnt_month        ID  \
# 11127999              34       45    18454             0.0  214195.0
# 11128000              34       45    16188             0.0  214196.0
# 11128001              34       45    15757             0.0  214197.0
# 11128002              34       45    19648             0.0  214198.0
# 11128003              34       45      969             0.0  214199.0
#
#           city_code  item_category_id  type_code  subtype_code
# 11127999         20                55         13             2
# 11128000         20                64         14            42
# 11128001         20                55         13             2
# 11128002         20                40         11             4
# 11128003         20                37         11             1

# %% [markdown]
# ## Traget lags

# %%
def lag_feature(df, lags, col):
    tmp = df[['date_block_num','shop_id','item_id',col]]
    for i in lags:
        shifted = tmp.copy()
        shifted.columns = ['date_block_num','shop_id','item_id', col+'_lag_'+str(i)]
        shifted['date_block_num'] += i
        df = pd.merge(df, shifted, on=['date_block_num','shop_id','item_id'], how='left')
    return df

# %%
ts = time.time()
matrix = lag_feature(matrix, [1,2,3,6,12], 'item_cnt_month')
time.time() - ts
matrix.shape
matrix.tail()
# Out:
# 27.10530424118042
# (11128004, 14)
#           date_block_num  shop_id  item_id  item_cnt_month        ID  \
# 11127999              34       45    18454             0.0  214195.0
# 11128000              34       45    16188             0.0  214196.0
# 11128001              34       45    15757             0.0  214197.0
# 11128002              34       45    19648             0.0  214198.0
# 11128003              34       45      969             0.0  214199.0
#
#           city_code  item_category_id  type_code  subtype_code  \
# 11127999         20                55         13             2
# 11128000         20                64         14            42
# 11128001         20                55         13             2
# 11128002         20                40         11             4
# 11128003         20                37         11             1
#
#           item_cnt_month_lag_1  item_cnt_month_lag_2  item_cnt_month_lag_3  \
# 11127999                   1.0                   0.0                   0.0
# 11128000                   0.0                   0.0                   NaN
# 11128001                   0.0                   0.0                   0.0
# 11128002                   0.0                   0.0                   0.0
# 11128003                   0.0                   0.0                   0.0
#
#           item_cnt_month_lag_6  item_cnt_month_lag_12
# 11127999                   0.0                    NaN
# 11128000                   NaN                    NaN
# 11128001                   0.0                    0.0
# 11128002                   0.0                    NaN
# 11128003                   0.0                    0.0

# %% [markdown]
# ## Mean encoded features

# %%
ts = time.time()
group = matrix.groupby(['date_block_num']).agg({'item_cnt_month': ['mean']})
group.columns = [ 'date_avg_item_cnt' ]
group.reset_index(inplace=True)

matrix = pd.merge(matrix, group, on=['date_block_num'], how='left')
matrix['date_avg_item_cnt'] = matrix['date_avg_item_cnt'].astype(np.float16)
matrix = lag_feature(matrix, [1], 'date_avg_item_cnt')
matrix.drop(['date_avg_item_cnt'], axis=1, inplace=True)
time.time() - ts
group.head()
matrix.shape
matrix.tail()
# Out:
# 8.793045043945312
#    date_block_num  date_avg_item_cnt
# 0               0           0.347168
# 1               1           0.324463
# 2               2           0.355469
# 3               3           0.275391
# 4               4           0.265137
# (11128004, 15)
#           date_block_num  shop_id  item_id  item_cnt_month        ID  \
# 11127999              34       45    18454             0.0  214195.0
# 11128000              34       45    16188             0.0  214196.0
# 11128001              34       45    15757             0.0  214197.0
# 11128002              34       45    19648             0.0  214198.0
# 11128003              34       45      969             0.0  214199.0
#
#           city_code  item_category_id  type_code  subtype_code  \
# 11127999         20                55         13             2
# 11128000         20                64         14            42
# 11128001         20                55         13             2
# 11128002         20                40         11             4
# 11128003         20                37         11             1
#
#           item_cnt_month_lag_1  item_cnt_month_lag_2  item_cnt_month_lag_3  \
# 11127999                   1.0                   0.0                   0.0
# 11128000                   0.0                   0.0                   NaN
# 11128001                   0.0                   0.0                   0.0
# 11128002                   0.0                   0.0                   0.0
# 11128003                   0.0                   0.0                   0.0
#
#           item_cnt_month_lag_6  item_cnt_month_lag_12  date_avg_item_cnt_lag_1
# 11127999                   0.0                    NaN                 0.258545
# 11128000                   NaN                    NaN                 0.258545
# 11128001                   0.0                    0.0                 0.258545
# 11128002                   0.0                    NaN                 0.258545
# 11128003                   0.0                    0.0                 0.258545

# %%
# item id
ts = time.time()
group = matrix.groupby(['date_block_num', 'item_id']).agg({'item_cnt_month': ['mean']})
group.columns = [ 'date_item_avg_item_cnt' ]
group.reset_index(inplace=True)

matrix = pd.merge(matrix, group, on=['date_block_num','item_id'], how='left')
matrix['date_item_avg_item_cnt'] = matrix['date_item_avg_item_cnt'].astype(np.float16)
matrix = lag_feature(matrix, [1,2,3,6,12], 'date_item_avg_item_cnt')
matrix.drop(['date_item_avg_item_cnt'], axis=1, inplace=True)

time.time() - ts
group.head()
matrix.shape
matrix.tail()
# Out:
# 33.112388134002686
#    date_block_num  item_id  date_item_avg_item_cnt
# 0               0       19                0.022217
# 1               0       27                0.155518
# 2               0       28                0.177734
# 3               0       29                0.088867
# 4               0       32                5.378906
# (11128004, 20)
#           date_block_num  shop_id  item_id  item_cnt_month        ID  \
# 11127999              34       45    18454             0.0  214195.0
# 11128000              34       45    16188             0.0  214196.0
# 11128001              34       45    15757             0.0  214197.0
# 11128002              34       45    19648             0.0  214198.0
# 11128003              34       45      969             0.0  214199.0
#
#           city_code  item_category_id  type_code  subtype_code  \
# 11127999         20                55         13             2
# 11128000         20                64         14            42
# 11128001         20                55         13             2
# 11128002         20                40         11             4
# 11128003         20                37         11             1
#
#           item_cnt_month_lag_1  item_cnt_month_lag_2  item_cnt_month_lag_3  \
# 11127999                   1.0                   0.0                   0.0
# 11128000                   0.0                   0.0                   NaN
# 11128001                   0.0                   0.0                   0.0
# 11128002                   0.0                   0.0                   0.0
# 11128003                   0.0                   0.0                   0.0
#
#           item_cnt_month_lag_6  item_cnt_month_lag_12  \
# 11127999                   0.0                    NaN
# 11128000                   NaN                    NaN
# 11128001                   0.0                    0.0
# 11128002                   0.0                    NaN
# 11128003                   0.0                    0.0
#
#           date_avg_item_cnt_lag_1  date_item_avg_item_cnt_lag_1  \
# 11127999                 0.258545                      0.045441
# 11128000                 0.258545                      0.022720
# 11128001                 0.258545                      0.113647
# 11128002                 0.258545                      0.045441
# 11128003                 0.258545                      0.068176
#
#           date_item_avg_item_cnt_lag_2  date_item_avg_item_cnt_lag_3  \
# 11127999                      0.023254                      0.071411
# 11128000                      0.069763                           NaN
# 11128001                      0.069763                      0.095215
# 11128002                      0.069763                      0.166626
# 11128003                      0.116272                      0.023804
#
#           date_item_avg_item_cnt_lag_6  date_item_avg_item_cnt_lag_12
# 11127999                      0.590820                            NaN
# 11128000                           NaN                            NaN
# 11128001                      0.250000                       0.180054
# 11128002                      0.090881                            NaN
# 11128003                      0.068176                       0.119995

# %%
# shop id
ts = time.time()
group = matrix.groupby(['date_block_num', 'shop_id']).agg({'item_cnt_month': ['mean']})
group.columns = [ 'date_shop_avg_item_cnt' ]
group.reset_index(inplace=True)

matrix = pd.merge(matrix, group, on=['date_block_num','shop_id'], how='left')
matrix['date_shop_avg_item_cnt'] = matrix['date_shop_avg_item_cnt'].astype(np.float16)
matrix = lag_feature(matrix, [1,2,3,6,12], 'date_shop_avg_item_cnt')
matrix.drop(['date_shop_avg_item_cnt'], axis=1, inplace=True)
time.time() - ts
group.head()
matrix.shape
matrix.tail()
# Out:
# 34.92278599739075
#    date_block_num  shop_id  date_shop_avg_item_cnt
# 0               0        2                0.141235
# 1               0        3                0.094543
# 2               0        4                0.257324
# 3               0        6                0.438721
# 4               0        7                0.305908
# (11128004, 25)
#           date_block_num  shop_id  item_id  item_cnt_month        ID  \
# 11127999              34       45    18454             0.0  214195.0
# 11128000              34       45    16188             0.0  214196.0
# 11128001              34       45    15757             0.0  214197.0
# 11128002              34       45    19648             0.0  214198.0
# 11128003              34       45      969             0.0  214199.0
#
#           city_code  item_category_id  type_code  subtype_code  \
# 11127999         20                55         13             2
# 11128000         20                64         14            42
# 11128001         20                55         13             2
# 11128002         20                40         11             4
# 11128003         20                37         11             1
#
#           item_cnt_month_lag_1  item_cnt_month_lag_2  item_cnt_month_lag_3  \
# 11127999                   1.0                   0.0                   0.0
# 11128000                   0.0                   0.0                   NaN
# 11128001                   0.0                   0.0                   0.0
# 11128002                   0.0                   0.0                   0.0
# 11128003                   0.0                   0.0                   0.0
#
#           item_cnt_month_lag_6  item_cnt_month_lag_12  \
# 11127999                   0.0                    NaN
# 11128000                   NaN                    NaN
# 11128001                   0.0                    0.0
# 11128002                   0.0                    NaN
# 11128003                   0.0                    0.0
#
#           date_avg_item_cnt_lag_1  date_item_avg_item_cnt_lag_1  \
# 11127999                 0.258545                      0.045441
# 11128000                 0.258545                      0.022720
# 11128001                 0.258545                      0.113647
# 11128002                 0.258545                      0.045441
# 11128003                 0.258545                      0.068176
#
#           date_item_avg_item_cnt_lag_2  date_item_avg_item_cnt_lag_3  \
# 11127999                      0.023254                      0.071411
# 11128000                      0.069763                           NaN
# 11128001                      0.069763                      0.095215
# 11128002                      0.069763                      0.166626
# 11128003                      0.116272                      0.023804
#
#           date_item_avg_item_cnt_lag_6  date_item_avg_item_cnt_lag_12  \
# 11127999                      0.590820                            NaN
# 11128000                           NaN                            NaN
# 11128001                      0.250000                       0.180054
# 11128002                      0.090881                            NaN
# 11128003                      0.068176                       0.119995
#
#           date_shop_avg_item_cnt_lag_1  date_shop_avg_item_cnt_lag_2  \
# 11127999                      0.126709                      0.128784
# 11128000                      0.126709                      0.128784
# 11128001                      0.126709                      0.128784
# 11128002                      0.126709                      0.128784
# 11128003                      0.126709                      0.128784
#
#           date_shop_avg_item_cnt_lag_3  date_shop_avg_item_cnt_lag_6  \
# 11127999                      0.139038                      0.137573
# 11128000                           NaN                           NaN
# 11128001                      0.139038                      0.137573
# 11128002                      0.139038                      0.137573
# 11128003                      0.139038                      0.137573
#
#           date_shop_avg_item_cnt_lag_12
# 11127999                            NaN
# 11128000                            NaN
# 11128001                       0.181274
# 11128002                            NaN
# 11128003                       0.181274

# %%
ts = time.time()
group = matrix.groupby(['date_block_num', 'item_category_id']).agg({'item_cnt_month': ['mean']})
group.columns = [ 'date_cat_avg_item_cnt' ]
group.reset_index(inplace=True)

matrix = pd.merge(matrix, group, on=['date_block_num','item_category_id'], how='left')
matrix['date_cat_avg_item_cnt'] = matrix['date_cat_avg_item_cnt'].astype(np.float16)
matrix = lag_feature(matrix, [1], 'date_cat_avg_item_cnt')
matrix.drop(['date_cat_avg_item_cnt'], axis=1, inplace=True)
time.time() - ts
group.head()
matrix.shape
matrix.tail()
# Out:
# 12.253175020217896
#    date_block_num  item_category_id  date_cat_avg_item_cnt
# 0               0                 0               0.022217
# 1               0                 1               0.022217
# 2               0                 2               0.835449
# 3               0                 3               4.421875
# 4               0                 4               0.513184
# (11128004, 26)
#           date_block_num  shop_id  item_id  item_cnt_month        ID  \
# 11127999              34       45    18454             0.0  214195.0
# 11128000              34       45    16188             0.0  214196.0
# 11128001              34       45    15757             0.0  214197.0
# 11128002              34       45    19648             0.0  214198.0
# 11128003              34       45      969             0.0  214199.0
#
#           city_code  item_category_id  type_code  subtype_code  \
# 11127999         20                55         13             2
# 11128000         20                64         14            42
# 11128001         20                55         13             2
# 11128002         20                40         11             4
# 11128003         20                37         11             1
#
#           item_cnt_month_lag_1  item_cnt_month_lag_2  item_cnt_month_lag_3  \
# 11127999                   1.0                   0.0                   0.0
# 11128000                   0.0                   0.0                   NaN
# 11128001                   0.0                   0.0                   0.0
# 11128002                   0.0                   0.0                   0.0
# 11128003                   0.0                   0.0                   0.0
#
#           item_cnt_month_lag_6  item_cnt_month_lag_12  \
# 11127999                   0.0                    NaN
# 11128000                   NaN                    NaN
# 11128001                   0.0                    0.0
# 11128002                   0.0                    NaN
# 11128003                   0.0                    0.0
#
#           date_avg_item_cnt_lag_1  date_item_avg_item_cnt_lag_1  \
# 11127999                 0.258545                      0.045441
# 11128000                 0.258545                      0.022720
# 11128001                 0.258545                      0.113647
# 11128002                 0.258545                      0.045441
# 11128003                 0.258545                      0.068176
#
#           date_item_avg_item_cnt_lag_2  date_item_avg_item_cnt_lag_3  \
# 11127999                      0.023254                      0.071411
# 11128000                      0.069763                           NaN
# 11128001                      0.069763                      0.095215
# 11128002                      0.069763                      0.166626
# 11128003                      0.116272                      0.023804
#
#           date_item_avg_item_cnt_lag_6  date_item_avg_item_cnt_lag_12  \
# 11127999                      0.590820                            NaN
# 11128000                           NaN                            NaN
# 11128001                      0.250000                       0.180054
# 11128002                      0.090881                            NaN
# 11128003                      0.068176                       0.119995
#
#           date_shop_avg_item_cnt_lag_1  date_shop_avg_item_cnt_lag_2  \
# 11127999                      0.126709                      0.128784
# 11128000                      0.126709                      0.128784
# 11128001                      0.126709                      0.128784
# 11128002                      0.126709                      0.128784
# 11128003                      0.126709                      0.128784
#
#           date_shop_avg_item_cnt_lag_3  date_shop_avg_item_cnt_lag_6  \
# 11127999                      0.139038                      0.137573
# 11128000                           NaN                           NaN
# 11128001                      0.139038                      0.137573
# 11128002                      0.139038                      0.137573
# 11128003                      0.139038                      0.137573
#
#           date_shop_avg_item_cnt_lag_12  date_cat_avg_item_cnt_lag_1
# 11127999                            NaN                     0.196899
# 11128000                            NaN                     0.155884
# 11128001                       0.181274                     0.196899
# 11128002                            NaN                     0.220825
# 11128003                       0.181274                     0.256836

# %%
ts = time.time()
group = matrix.groupby(['date_block_num', 'shop_id', 'item_category_id']).agg({'item_cnt_month': ['mean']})
group.columns = ['date_shop_cat_avg_item_cnt']
group.reset_index(inplace=True)

matrix = pd.merge(matrix, group, on=['date_block_num', 'shop_id', 'item_category_id'], how='left')
matrix['date_shop_cat_avg_item_cnt'] = matrix['date_shop_cat_avg_item_cnt'].astype(np.float16)
matrix = lag_feature(matrix, [1], 'date_shop_cat_avg_item_cnt')
matrix.drop(['date_shop_cat_avg_item_cnt'], axis=1, inplace=True)
time.time() - ts
group.head()
matrix.shape
matrix.tail()
# Out:
# 13.072134017944336
#    date_block_num  shop_id  item_category_id  date_shop_cat_avg_item_cnt
# 0               0        2                 0                    0.000000
# 1               0        2                 1                    0.000000
# 2               0        2                 2                    0.675781
# 3               0        2                 3                    4.500000
# 4               0        2                 4                    0.909180
# (11128004, 27)
#           date_block_num  shop_id  item_id  item_cnt_month        ID  \
# 11127999              34       45    18454             0.0  214195.0
# 11128000              34       45    16188             0.0  214196.0
# 11128001              34       45    15757             0.0  214197.0
# 11128002              34       45    19648             0.0  214198.0
# 11128003              34       45      969             0.0  214199.0
#
#           city_code  item_category_id  type_code  subtype_code  \
# 11127999         20                55         13             2
# 11128000         20                64         14            42
# 11128001         20                55         13             2
# 11128002         20                40         11             4
# 11128003         20                37         11             1
#
#           item_cnt_month_lag_1  item_cnt_month_lag_2  item_cnt_month_lag_3  \
# 11127999                   1.0                   0.0                   0.0
# 11128000                   0.0                   0.0                   NaN
# 11128001                   0.0                   0.0                   0.0
# 11128002                   0.0                   0.0                   0.0
# 11128003                   0.0                   0.0                   0.0
#
#           item_cnt_month_lag_6  item_cnt_month_lag_12  \
# 11127999                   0.0                    NaN
# 11128000                   NaN                    NaN
# 11128001                   0.0                    0.0
# 11128002                   0.0                    NaN
# 11128003                   0.0                    0.0
#
#           date_avg_item_cnt_lag_1  date_item_avg_item_cnt_lag_1  \
# 11127999                 0.258545                      0.045441
# 11128000                 0.258545                      0.022720
# 11128001                 0.258545                      0.113647
# 11128002                 0.258545                      0.045441
# 11128003                 0.258545                      0.068176
#
#           date_item_avg_item_cnt_lag_2  date_item_avg_item_cnt_lag_3  \
# 11127999                      0.023254                      0.071411
# 11128000                      0.069763                           NaN
# 11128001                      0.069763                      0.095215
# 11128002                      0.069763                      0.166626
# 11128003                      0.116272                      0.023804
#
#           date_item_avg_item_cnt_lag_6  date_item_avg_item_cnt_lag_12  \
# 11127999                      0.590820                            NaN
# 11128000                           NaN                            NaN
# 11128001                      0.250000                       0.180054
# 11128002                      0.090881                            NaN
# 11128003                      0.068176                       0.119995
#
#           date_shop_avg_item_cnt_lag_1  date_shop_avg_item_cnt_lag_2  \
# 11127999                      0.126709                      0.128784
# 11128000                      0.126709                      0.128784
# 11128001                      0.126709                      0.128784
# 11128002                      0.126709                      0.128784
# 11128003                      0.126709                      0.128784
#
#           date_shop_avg_item_cnt_lag_3  date_shop_avg_item_cnt_lag_6  \
# 11127999                      0.139038                      0.137573
# 11128000                           NaN                           NaN
# 11128001                      0.139038                      0.137573
# 11128002                      0.139038                      0.137573
# 11128003                      0.139038                      0.137573
#
#           date_shop_avg_item_cnt_lag_12  date_cat_avg_item_cnt_lag_1  \
# 11127999                            NaN                     0.196899
# 11128000                            NaN                     0.155884
# 11128001                       0.181274                     0.196899
# 11128002                            NaN                     0.220825
# 11128003                       0.181274                     0.256836
#
#           date_shop_cat_avg_item_cnt_lag_1
# 11127999                          0.126831
# 11128000                          0.094482
# 11128001                          0.126831
# 11128002                          0.083740
# 11128003                          0.128174

# %%
ts = time.time()
group = matrix.groupby(['date_block_num', 'shop_id', 'type_code']).agg({'item_cnt_month': ['mean']})
group.columns = ['date_shop_type_avg_item_cnt']
group.reset_index(inplace=True)

matrix = pd.merge(matrix, group, on=['date_block_num', 'shop_id', 'type_code'], how='left')
matrix['date_shop_type_avg_item_cnt'] = matrix['date_shop_type_avg_item_cnt'].astype(np.float16)
matrix = lag_feature(matrix, [1], 'date_shop_type_avg_item_cnt')
matrix.drop(['date_shop_type_avg_item_cnt'], axis=1, inplace=True)
time.time() - ts
group.head()
matrix.shape
matrix.tail()
# Out:
# 13.613234043121338
#    date_block_num  shop_id  type_code  date_shop_type_avg_item_cnt
# 0               0        2          0                     0.000000
# 1               0        2          1                     0.680176
# 2               0        2          3                     0.000000
# 3               0        2          4                     0.444336
# 4               0        2          5                     0.427002
# (11128004, 28)
#           date_block_num  shop_id  item_id  item_cnt_month        ID  \
# 11127999              34       45    18454             0.0  214195.0
# 11128000              34       45    16188             0.0  214196.0
# 11128001              34       45    15757             0.0  214197.0
# 11128002              34       45    19648             0.0  214198.0
# 11128003              34       45      969             0.0  214199.0
#
#           city_code  item_category_id  type_code  subtype_code  \
# 11127999         20                55         13             2
# 11128000         20                64         14            42
# 11128001         20                55         13             2
# 11128002         20                40         11             4
# 11128003         20                37         11             1
#
#           item_cnt_month_lag_1  item_cnt_month_lag_2  item_cnt_month_lag_3  \
# 11127999                   1.0                   0.0                   0.0
# 11128000                   0.0                   0.0                   NaN
# 11128001                   0.0                   0.0                   0.0
# 11128002                   0.0                   0.0                   0.0
# 11128003                   0.0                   0.0                   0.0
#
#           item_cnt_month_lag_6  item_cnt_month_lag_12  \
# 11127999                   0.0                    NaN
# 11128000                   NaN                    NaN
# 11128001                   0.0                    0.0
# 11128002                   0.0                    NaN
# 11128003                   0.0                    0.0
#
#           date_avg_item_cnt_lag_1  date_item_avg_item_cnt_lag_1  \
# 11127999                 0.258545                      0.045441
# 11128000                 0.258545                      0.022720
# 11128001                 0.258545                      0.113647
# 11128002                 0.258545                      0.045441
# 11128003                 0.258545                      0.068176
#
#           date_item_avg_item_cnt_lag_2  date_item_avg_item_cnt_lag_3  \
# 11127999                      0.023254                      0.071411
# 11128000                      0.069763                           NaN
# 11128001                      0.069763                      0.095215
# 11128002                      0.069763                      0.166626
# 11128003                      0.116272                      0.023804
#
#           date_item_avg_item_cnt_lag_6  date_item_avg_item_cnt_lag_12  \
# 11127999                      0.590820                            NaN
# 11128000                           NaN                            NaN
# 11128001                      0.250000                       0.180054
# 11128002                      0.090881                            NaN
# 11128003                      0.068176                       0.119995
#
#           date_shop_avg_item_cnt_lag_1  date_shop_avg_item_cnt_lag_2  \
# 11127999                      0.126709                      0.128784
# 11128000                      0.126709                      0.128784
# 11128001                      0.126709                      0.128784
# 11128002                      0.126709                      0.128784
# 11128003                      0.126709                      0.128784
#
#           date_shop_avg_item_cnt_lag_3  date_shop_avg_item_cnt_lag_6  \
# 11127999                      0.139038                      0.137573
# 11128000                           NaN                           NaN
# 11128001                      0.139038                      0.137573
# 11128002                      0.139038                      0.137573
# 11128003                      0.139038                      0.137573
#
#           date_shop_avg_item_cnt_lag_12  date_cat_avg_item_cnt_lag_1  \
# 11127999                            NaN                     0.196899
# 11128000                            NaN                     0.155884
# 11128001                       0.181274                     0.196899
# 11128002                            NaN                     0.220825
# 11128003                       0.181274                     0.256836
#
#           date_shop_cat_avg_item_cnt_lag_1  date_shop_type_avg_item_cnt_lag_1
# 11127999                          0.126831                           0.089294
# 11128000                          0.094482                           0.106201
# 11128001                          0.126831                           0.089294
# 11128002                          0.083740                           0.097046
# 11128003                          0.128174                           0.097046

# %%
ts = time.time()
group = matrix.groupby(['date_block_num', 'shop_id', 'subtype_code']).agg({'item_cnt_month': ['mean']})
group.columns = ['date_shop_subtype_avg_item_cnt']
group.reset_index(inplace=True)

matrix = pd.merge(matrix, group, on=['date_block_num', 'shop_id', 'subtype_code'], how='left')
matrix['date_shop_subtype_avg_item_cnt'] = matrix['date_shop_subtype_avg_item_cnt'].astype(np.float16)
matrix = lag_feature(matrix, [1], 'date_shop_subtype_avg_item_cnt')
matrix.drop(['date_shop_subtype_avg_item_cnt'], axis=1, inplace=True)
time.time() - ts
group.head()
matrix.shape
matrix.tail()
# Out:
# 14.029489994049072
#    date_block_num  shop_id  subtype_code  date_shop_subtype_avg_item_cnt
# 0               0        2             0                        0.388916
# 1               0        2             1                        0.085632
# 2               0        2             2                        0.030670
# 3               0        2             3                        0.000000
# 4               0        2             4                        0.073120
# (11128004, 29)
#           date_block_num  shop_id  item_id  item_cnt_month        ID  \
# 11127999              34       45    18454             0.0  214195.0
# 11128000              34       45    16188             0.0  214196.0
# 11128001              34       45    15757             0.0  214197.0
# 11128002              34       45    19648             0.0  214198.0
# 11128003              34       45      969             0.0  214199.0
#
#           city_code  item_category_id  type_code  subtype_code  \
# 11127999         20                55         13             2
# 11128000         20                64         14            42
# 11128001         20                55         13             2
# 11128002         20                40         11             4
# 11128003         20                37         11             1
#
#           item_cnt_month_lag_1  item_cnt_month_lag_2  item_cnt_month_lag_3  \
# 11127999                   1.0                   0.0                   0.0
# 11128000                   0.0                   0.0                   NaN
# 11128001                   0.0                   0.0                   0.0
# 11128002                   0.0                   0.0                   0.0
# 11128003                   0.0                   0.0                   0.0
#
#           item_cnt_month_lag_6  item_cnt_month_lag_12  \
# 11127999                   0.0                    NaN
# 11128000                   NaN                    NaN
# 11128001                   0.0                    0.0
# 11128002                   0.0                    NaN
# 11128003                   0.0                    0.0
#
#           date_avg_item_cnt_lag_1  date_item_avg_item_cnt_lag_1  \
# 11127999                 0.258545                      0.045441
# 11128000                 0.258545                      0.022720
# 11128001                 0.258545                      0.113647
# 11128002                 0.258545                      0.045441
# 11128003                 0.258545                      0.068176
#
#           date_item_avg_item_cnt_lag_2  date_item_avg_item_cnt_lag_3  \
# 11127999                      0.023254                      0.071411
# 11128000                      0.069763                           NaN
# 11128001                      0.069763                      0.095215
# 11128002                      0.069763                      0.166626
# 11128003                      0.116272                      0.023804
#
#           date_item_avg_item_cnt_lag_6  date_item_avg_item_cnt_lag_12  \
# 11127999                      0.590820                            NaN
# 11128000                           NaN                            NaN
# 11128001                      0.250000                       0.180054
# 11128002                      0.090881                            NaN
# 11128003                      0.068176                       0.119995
#
#           date_shop_avg_item_cnt_lag_1  date_shop_avg_item_cnt_lag_2  \
# 11127999                      0.126709                      0.128784
# 11128000                      0.126709                      0.128784
# 11128001                      0.126709                      0.128784
# 11128002                      0.126709                      0.128784
# 11128003                      0.126709                      0.128784
#
#           date_shop_avg_item_cnt_lag_3  date_shop_avg_item_cnt_lag_6  \
# 11127999                      0.139038                      0.137573
# 11128000                           NaN                           NaN
# 11128001                      0.139038                      0.137573
# 11128002                      0.139038                      0.137573
# 11128003                      0.139038                      0.137573
#
#           date_shop_avg_item_cnt_lag_12  date_cat_avg_item_cnt_lag_1  \
# 11127999                            NaN                     0.196899
# 11128000                            NaN                     0.155884
# 11128001                       0.181274                     0.196899
# 11128002                            NaN                     0.220825
# 11128003                       0.181274                     0.256836
#
#           date_shop_cat_avg_item_cnt_lag_1  date_shop_type_avg_item_cnt_lag_1  \
# 11127999                          0.126831                           0.089294
# 11128000                          0.094482                           0.106201
# 11128001                          0.126831                           0.089294
# 11128002                          0.083740                           0.097046
# 11128003                          0.128174                           0.097046
#
#           date_shop_subtype_avg_item_cnt_lag_1
# 11127999                              0.126831
# 11128000                              0.094482
# 11128001                              0.126831
# 11128002                              0.083740
# 11128003                              0.126343

# %%
ts = time.time()
group = matrix.groupby(['date_block_num', 'city_code']).agg({'item_cnt_month': ['mean']})
group.columns = [ 'date_city_avg_item_cnt' ]
group.reset_index(inplace=True)

matrix = pd.merge(matrix, group, on=['date_block_num', 'city_code'], how='left')
matrix['date_city_avg_item_cnt'] = matrix['date_city_avg_item_cnt'].astype(np.float16)
matrix = lag_feature(matrix, [1], 'date_city_avg_item_cnt')
matrix.drop(['date_city_avg_item_cnt'], axis=1, inplace=True)
time.time() - ts
group.head()
matrix.shape
matrix.tail()
# Out:
# 14.27950382232666
#    date_block_num  city_code  date_city_avg_item_cnt
# 0               0          0                0.141235
# 1               0          1                0.094543
# 2               0          2                0.257324
# 3               0          4                0.308350
# 4               0          6                0.115234
# (11128004, 30)
#           date_block_num  shop_id  item_id  item_cnt_month        ID  \
# 11127999              34       45    18454             0.0  214195.0
# 11128000              34       45    16188             0.0  214196.0
# 11128001              34       45    15757             0.0  214197.0
# 11128002              34       45    19648             0.0  214198.0
# 11128003              34       45      969             0.0  214199.0
#
#           city_code  item_category_id  type_code  subtype_code  \
# 11127999         20                55         13             2
# 11128000         20                64         14            42
# 11128001         20                55         13             2
# 11128002         20                40         11             4
# 11128003         20                37         11             1
#
#           item_cnt_month_lag_1  item_cnt_month_lag_2  item_cnt_month_lag_3  \
# 11127999                   1.0                   0.0                   0.0
# 11128000                   0.0                   0.0                   NaN
# 11128001                   0.0                   0.0                   0.0
# 11128002                   0.0                   0.0                   0.0
# 11128003                   0.0                   0.0                   0.0
#
#           item_cnt_month_lag_6  item_cnt_month_lag_12  \
# 11127999                   0.0                    NaN
# 11128000                   NaN                    NaN
# 11128001                   0.0                    0.0
# 11128002                   0.0                    NaN
# 11128003                   0.0                    0.0
#
#           date_avg_item_cnt_lag_1  date_item_avg_item_cnt_lag_1  \
# 11127999                 0.258545                      0.045441
# 11128000                 0.258545                      0.022720
# 11128001                 0.258545                      0.113647
# 11128002                 0.258545                      0.045441
# 11128003                 0.258545                      0.068176
#
#           date_item_avg_item_cnt_lag_2  date_item_avg_item_cnt_lag_3  \
# 11127999                      0.023254                      0.071411
# 11128000                      0.069763                           NaN
# 11128001                      0.069763                      0.095215
# 11128002                      0.069763                      0.166626
# 11128003                      0.116272                      0.023804
#
#           date_item_avg_item_cnt_lag_6  date_item_avg_item_cnt_lag_12  \
# 11127999                      0.590820                            NaN
# 11128000                           NaN                            NaN
# 11128001                      0.250000                       0.180054
# 11128002                      0.090881                            NaN
# 11128003                      0.068176                       0.119995
#
#           date_shop_avg_item_cnt_lag_1  date_shop_avg_item_cnt_lag_2  \
# 11127999                      0.126709                      0.128784
# 11128000                      0.126709                      0.128784
# 11128001                      0.126709                      0.128784
# 11128002                      0.126709                      0.128784
# 11128003                      0.126709                      0.128784
#
#           date_shop_avg_item_cnt_lag_3  date_shop_avg_item_cnt_lag_6  \
# 11127999                      0.139038                      0.137573
# 11128000                           NaN                           NaN
# 11128001                      0.139038                      0.137573
# 11128002                      0.139038                      0.137573
# 11128003                      0.139038                      0.137573
#
#           date_shop_avg_item_cnt_lag_12  date_cat_avg_item_cnt_lag_1  \
# 11127999                            NaN                     0.196899
# 11128000                            NaN                     0.155884
# 11128001                       0.181274                     0.196899
# 11128002                            NaN                     0.220825
# 11128003                       0.181274                     0.256836
#
#           date_shop_cat_avg_item_cnt_lag_1  date_shop_type_avg_item_cnt_lag_1  \
# 11127999                          0.126831                           0.089294
# 11128000                          0.094482                           0.106201
# 11128001                          0.126831                           0.089294
# 11128002                          0.083740                           0.097046
# 11128003                          0.128174                           0.097046
#
#           date_shop_subtype_avg_item_cnt_lag_1  date_city_avg_item_cnt_lag_1
# 11127999                              0.126831                      0.135376
# 11128000                              0.094482                      0.135376
# 11128001                              0.126831                      0.135376
# 11128002                              0.083740                      0.135376
# 11128003                              0.126343                      0.135376

# %%
# city code
ts = time.time()
group = matrix.groupby(['date_block_num', 'item_id', 'city_code']).agg({'item_cnt_month': ['mean']})
group.columns = [ 'date_item_city_avg_item_cnt' ]
group.reset_index(inplace=True)

matrix = pd.merge(matrix, group, on=['date_block_num', 'item_id', 'city_code'], how='left')
matrix['date_item_city_avg_item_cnt'] = matrix['date_item_city_avg_item_cnt'].astype(np.float16)
matrix = lag_feature(matrix, [1], 'date_item_city_avg_item_cnt')
matrix.drop(['date_item_city_avg_item_cnt'], axis=1, inplace=True)
time.time() - ts
group.head()
matrix.shape
matrix.tail()
# Out:
# 21.78199791908264
#    date_block_num  item_id  city_code  date_item_city_avg_item_cnt
# 0               0       19          0                          0.0
# 1               0       19          1                          0.0
# 2               0       19          2                          0.0
# 3               0       19          4                          0.0
# 4               0       19          6                          0.0
# (11128004, 31)
#           date_block_num  shop_id  item_id  item_cnt_month        ID  \
# 11127999              34       45    18454             0.0  214195.0
# 11128000              34       45    16188             0.0  214196.0
# 11128001              34       45    15757             0.0  214197.0
# 11128002              34       45    19648             0.0  214198.0
# 11128003              34       45      969             0.0  214199.0
#
#           city_code  item_category_id  type_code  subtype_code  \
# 11127999         20                55         13             2
# 11128000         20                64         14            42
# 11128001         20                55         13             2
# 11128002         20                40         11             4
# 11128003         20                37         11             1
#
#           item_cnt_month_lag_1  item_cnt_month_lag_2  item_cnt_month_lag_3  \
# 11127999                   1.0                   0.0                   0.0
# 11128000                   0.0                   0.0                   NaN
# 11128001                   0.0                   0.0                   0.0
# 11128002                   0.0                   0.0                   0.0
# 11128003                   0.0                   0.0                   0.0
#
#           item_cnt_month_lag_6  item_cnt_month_lag_12  \
# 11127999                   0.0                    NaN
# 11128000                   NaN                    NaN
# 11128001                   0.0                    0.0
# 11128002                   0.0                    NaN
# 11128003                   0.0                    0.0
#
#           date_avg_item_cnt_lag_1  date_item_avg_item_cnt_lag_1  \
# 11127999                 0.258545                      0.045441
# 11128000                 0.258545                      0.022720
# 11128001                 0.258545                      0.113647
# 11128002                 0.258545                      0.045441
# 11128003                 0.258545                      0.068176
#
#           date_item_avg_item_cnt_lag_2  date_item_avg_item_cnt_lag_3  \
# 11127999                      0.023254                      0.071411
# 11128000                      0.069763                           NaN
# 11128001                      0.069763                      0.095215
# 11128002                      0.069763                      0.166626
# 11128003                      0.116272                      0.023804
#
#           date_item_avg_item_cnt_lag_6  date_item_avg_item_cnt_lag_12  \
# 11127999                      0.590820                            NaN
# 11128000                           NaN                            NaN
# 11128001                      0.250000                       0.180054
# 11128002                      0.090881                            NaN
# 11128003                      0.068176                       0.119995
#
#           date_shop_avg_item_cnt_lag_1  date_shop_avg_item_cnt_lag_2  \
# 11127999                      0.126709                      0.128784
# 11128000                      0.126709                      0.128784
# 11128001                      0.126709                      0.128784
# 11128002                      0.126709                      0.128784
# 11128003                      0.126709                      0.128784
#
#           date_shop_avg_item_cnt_lag_3  date_shop_avg_item_cnt_lag_6  \
# 11127999                      0.139038                      0.137573
# 11128000                           NaN                           NaN
# 11128001                      0.139038                      0.137573
# 11128002                      0.139038                      0.137573
# 11128003                      0.139038                      0.137573
#
#           date_shop_avg_item_cnt_lag_12  date_cat_avg_item_cnt_lag_1  \
# 11127999                            NaN                     0.196899
# 11128000                            NaN                     0.155884
# 11128001                       0.181274                     0.196899
# 11128002                            NaN                     0.220825
# 11128003                       0.181274                     0.256836
#
#           date_shop_cat_avg_item_cnt_lag_1  date_shop_type_avg_item_cnt_lag_1  \
# 11127999                          0.126831                           0.089294
# 11128000                          0.094482                           0.106201
# 11128001                          0.126831                           0.089294
# 11128002                          0.083740                           0.097046
# 11128003                          0.128174                           0.097046
#
#           date_shop_subtype_avg_item_cnt_lag_1  date_city_avg_item_cnt_lag_1  \
# 11127999                              0.126831                      0.135376
# 11128000                              0.094482                      0.135376
# 11128001                              0.126831                      0.135376
# 11128002                              0.083740                      0.135376
# 11128003                              0.126343                      0.135376
#
#           date_item_city_avg_item_cnt_lag_1
# 11127999                                0.5
# 11128000                                0.0
# 11128001                                0.0
# 11128002                                0.0
# 11128003                                0.5

# %%
#type code
ts = time.time()
group = matrix.groupby(['date_block_num', 'type_code']).agg({'item_cnt_month': ['mean']})
group.columns = [ 'date_type_avg_item_cnt' ]
group.reset_index(inplace=True)

matrix = pd.merge(matrix, group, on=['date_block_num', 'type_code'], how='left')
matrix['date_type_avg_item_cnt'] = matrix['date_type_avg_item_cnt'].astype(np.float16)
matrix = lag_feature(matrix, [1], 'date_type_avg_item_cnt')
matrix.drop(['date_type_avg_item_cnt'], axis=1, inplace=True)
time.time() - ts
matrix.shape
matrix.tail()
# Out:
# 15.907857894897461
# (11128004, 32)
#           date_block_num  shop_id  item_id  item_cnt_month        ID  \
# 11127999              34       45    18454             0.0  214195.0
# 11128000              34       45    16188             0.0  214196.0
# 11128001              34       45    15757             0.0  214197.0
# 11128002              34       45    19648             0.0  214198.0
# 11128003              34       45      969             0.0  214199.0
#
#           city_code  item_category_id  type_code  subtype_code  \
# 11127999         20                55         13             2
# 11128000         20                64         14            42
# 11128001         20                55         13             2
# 11128002         20                40         11             4
# 11128003         20                37         11             1
#
#           item_cnt_month_lag_1  item_cnt_month_lag_2  item_cnt_month_lag_3  \
# 11127999                   1.0                   0.0                   0.0
# 11128000                   0.0                   0.0                   NaN
# 11128001                   0.0                   0.0                   0.0
# 11128002                   0.0                   0.0                   0.0
# 11128003                   0.0                   0.0                   0.0
#
#           item_cnt_month_lag_6  item_cnt_month_lag_12  \
# 11127999                   0.0                    NaN
# 11128000                   NaN                    NaN
# 11128001                   0.0                    0.0
# 11128002                   0.0                    NaN
# 11128003                   0.0                    0.0
#
#           date_avg_item_cnt_lag_1  date_item_avg_item_cnt_lag_1  \
# 11127999                 0.258545                      0.045441
# 11128000                 0.258545                      0.022720
# 11128001                 0.258545                      0.113647
# 11128002                 0.258545                      0.045441
# 11128003                 0.258545                      0.068176
#
#           date_item_avg_item_cnt_lag_2  date_item_avg_item_cnt_lag_3  \
# 11127999                      0.023254                      0.071411
# 11128000                      0.069763                           NaN
# 11128001                      0.069763                      0.095215
# 11128002                      0.069763                      0.166626
# 11128003                      0.116272                      0.023804
#
#           date_item_avg_item_cnt_lag_6  date_item_avg_item_cnt_lag_12  \
# 11127999                      0.590820                            NaN
# 11128000                           NaN                            NaN
# 11128001                      0.250000                       0.180054
# 11128002                      0.090881                            NaN
# 11128003                      0.068176                       0.119995
#
#           date_shop_avg_item_cnt_lag_1  date_shop_avg_item_cnt_lag_2  \
# 11127999                      0.126709                      0.128784
# 11128000                      0.126709                      0.128784
# 11128001                      0.126709                      0.128784
# 11128002                      0.126709                      0.128784
# 11128003                      0.126709                      0.128784
#
#           date_shop_avg_item_cnt_lag_3  date_shop_avg_item_cnt_lag_6  \
# 11127999                      0.139038                      0.137573
# 11128000                           NaN                           NaN
# 11128001                      0.139038                      0.137573
# 11128002                      0.139038                      0.137573
# 11128003                      0.139038                      0.137573
#
#           date_shop_avg_item_cnt_lag_12  date_cat_avg_item_cnt_lag_1  \
# 11127999                            NaN                     0.196899
# 11128000                            NaN                     0.155884
# 11128001                       0.181274                     0.196899
# 11128002                            NaN                     0.220825
# 11128003                       0.181274                     0.256836
#
#           date_shop_cat_avg_item_cnt_lag_1  date_shop_type_avg_item_cnt_lag_1  \
# 11127999                          0.126831                           0.089294
# 11128000                          0.094482                           0.106201
# 11128001                          0.126831                           0.089294
# 11128002                          0.083740                           0.097046
# 11128003                          0.128174                           0.097046
#
#           date_shop_subtype_avg_item_cnt_lag_1  date_city_avg_item_cnt_lag_1  \
# 11127999                              0.126831                      0.135376
# 11128000                              0.094482                      0.135376
# 11128001                              0.126831                      0.135376
# 11128002                              0.083740                      0.135376
# 11128003                              0.126343                      0.135376
#
#           date_item_city_avg_item_cnt_lag_1  date_type_avg_item_cnt_lag_1
# 11127999                                0.5                      0.146973
# 11128000                                0.0                      0.237305
# 11128001                                0.0                      0.146973
# 11128002                                0.0                      0.224243
# 11128003                                0.5                      0.224243

# %%
#subtype code
ts = time.time()
group = matrix.groupby(['date_block_num', 'subtype_code']).agg({'item_cnt_month': ['mean']})
group.columns = [ 'date_subtype_avg_item_cnt' ]
group.reset_index(inplace=True)

matrix = pd.merge(matrix, group, on=['date_block_num', 'subtype_code'], how='left')
matrix['date_subtype_avg_item_cnt'] = matrix['date_subtype_avg_item_cnt'].astype(np.float16)
matrix = lag_feature(matrix, [1], 'date_subtype_avg_item_cnt')
matrix.drop(['date_subtype_avg_item_cnt'], axis=1, inplace=True)
time.time() - ts
matrix.shape
matrix.tail()
# Out:
# 15.768986701965332
# (11128004, 33)
#           date_block_num  shop_id  item_id  item_cnt_month        ID  \
# 11127999              34       45    18454             0.0  214195.0
# 11128000              34       45    16188             0.0  214196.0
# 11128001              34       45    15757             0.0  214197.0
# 11128002              34       45    19648             0.0  214198.0
# 11128003              34       45      969             0.0  214199.0
#
#           city_code  item_category_id  type_code  subtype_code  \
# 11127999         20                55         13             2
# 11128000         20                64         14            42
# 11128001         20                55         13             2
# 11128002         20                40         11             4
# 11128003         20                37         11             1
#
#           item_cnt_month_lag_1  item_cnt_month_lag_2  item_cnt_month_lag_3  \
# 11127999                   1.0                   0.0                   0.0
# 11128000                   0.0                   0.0                   NaN
# 11128001                   0.0                   0.0                   0.0
# 11128002                   0.0                   0.0                   0.0
# 11128003                   0.0                   0.0                   0.0
#
#           item_cnt_month_lag_6  item_cnt_month_lag_12  \
# 11127999                   0.0                    NaN
# 11128000                   NaN                    NaN
# 11128001                   0.0                    0.0
# 11128002                   0.0                    NaN
# 11128003                   0.0                    0.0
#
#           date_avg_item_cnt_lag_1  date_item_avg_item_cnt_lag_1  \
# 11127999                 0.258545                      0.045441
# 11128000                 0.258545                      0.022720
# 11128001                 0.258545                      0.113647
# 11128002                 0.258545                      0.045441
# 11128003                 0.258545                      0.068176
#
#           date_item_avg_item_cnt_lag_2  date_item_avg_item_cnt_lag_3  \
# 11127999                      0.023254                      0.071411
# 11128000                      0.069763                           NaN
# 11128001                      0.069763                      0.095215
# 11128002                      0.069763                      0.166626
# 11128003                      0.116272                      0.023804
#
#           date_item_avg_item_cnt_lag_6  date_item_avg_item_cnt_lag_12  \
# 11127999                      0.590820                            NaN
# 11128000                           NaN                            NaN
# 11128001                      0.250000                       0.180054
# 11128002                      0.090881                            NaN
# 11128003                      0.068176                       0.119995
#
#           date_shop_avg_item_cnt_lag_1  date_shop_avg_item_cnt_lag_2  \
# 11127999                      0.126709                      0.128784
# 11128000                      0.126709                      0.128784
# 11128001                      0.126709                      0.128784
# 11128002                      0.126709                      0.128784
# 11128003                      0.126709                      0.128784
#
#           date_shop_avg_item_cnt_lag_3  date_shop_avg_item_cnt_lag_6  \
# 11127999                      0.139038                      0.137573
# 11128000                           NaN                           NaN
# 11128001                      0.139038                      0.137573
# 11128002                      0.139038                      0.137573
# 11128003                      0.139038                      0.137573
#
#           date_shop_avg_item_cnt_lag_12  date_cat_avg_item_cnt_lag_1  \
# 11127999                            NaN                     0.196899
# 11128000                            NaN                     0.155884
# 11128001                       0.181274                     0.196899
# 11128002                            NaN                     0.220825
# 11128003                       0.181274                     0.256836
#
#           date_shop_cat_avg_item_cnt_lag_1  date_shop_type_avg_item_cnt_lag_1  \
# 11127999                          0.126831                           0.089294
# 11128000                          0.094482                           0.106201
# 11128001                          0.126831                           0.089294
# 11128002                          0.083740                           0.097046
# 11128003                          0.128174                           0.097046
#
#           date_shop_subtype_avg_item_cnt_lag_1  date_city_avg_item_cnt_lag_1  \
# 11127999                              0.126831                      0.135376
# 11128000                              0.094482                      0.135376
# 11128001                              0.126831                      0.135376
# 11128002                              0.083740                      0.135376
# 11128003                              0.126343                      0.135376
#
#           date_item_city_avg_item_cnt_lag_1  date_type_avg_item_cnt_lag_1  \
# 11127999                                0.5                      0.146973
# 11128000                                0.0                      0.237305
# 11128001                                0.0                      0.146973
# 11128002                                0.0                      0.224243
# 11128003                                0.5                      0.224243
#
#           date_subtype_avg_item_cnt_lag_1
# 11127999                         0.196899
# 11128000                         0.155884
# 11128001                         0.196899
# 11128002                         0.220825
# 11128003                         0.240967

# %% [markdown]
# ## Trend features

# %% [markdown]
# Price trend for the last six months.

# %%
ts = time.time()
group = train.groupby(['item_id']).agg({'item_price': ['mean']})
group.columns = ['item_avg_item_price']
group.reset_index(inplace=True)

matrix = pd.merge(matrix, group, on=['item_id'], how='left')
matrix['item_avg_item_price'] = matrix['item_avg_item_price'].astype(np.float16)
matrix.shape
matrix.tail()


group = train.groupby(['date_block_num','item_id']).agg({'item_price': ['mean']})
group.columns = ['date_item_avg_item_price']
group.reset_index(inplace=True)

matrix = pd.merge(matrix, group, on=['date_block_num','item_id'], how='left')
matrix['date_item_avg_item_price'] = matrix['date_item_avg_item_price'].astype(np.float16)
matrix.shape
matrix.tail()
lags = [1,2,3,4,5,6]
matrix = lag_feature(matrix, lags, 'date_item_avg_item_price')

for i in lags:
    matrix['delta_price_lag_'+str(i)] = \
        (matrix['date_item_avg_item_price_lag_'+str(i)] - matrix['item_avg_item_price']) / matrix['item_avg_item_price']

def select_trend(row):
    for i in lags:
        if row['delta_price_lag_'+str(i)]:
            return row['delta_price_lag_'+str(i)]
    return 0
    
matrix['delta_price_lag'] = matrix.apply(select_trend, axis=1)
matrix['delta_price_lag'] = matrix['delta_price_lag'].astype(np.float16)
matrix['delta_price_lag'].fillna(0, inplace=True)
matrix.shape
matrix.tail()

# https://stackoverflow.com/questions/31828240/first-non-null-value-per-row-from-a-list-of-pandas-columns/31828559
# matrix['price_trend'] = matrix[['delta_price_lag_1','delta_price_lag_2','delta_price_lag_3']].bfill(axis=1).iloc[:, 0]
# Invalid dtype for backfill_2d [float16]

fetures_to_drop = ['item_avg_item_price', 'date_item_avg_item_price']
for i in lags:
    fetures_to_drop += ['date_item_avg_item_price_lag_'+str(i)]
    fetures_to_drop += ['delta_price_lag_'+str(i)]

matrix.drop(fetures_to_drop, axis=1, inplace=True)
matrix.shape
matrix.tail()

time.time() - ts
# Out:
# (11128004, 34)
#           date_block_num  shop_id  item_id  item_cnt_month        ID  \
# 11127999              34       45    18454             0.0  214195.0
# 11128000              34       45    16188             0.0  214196.0
# 11128001              34       45    15757             0.0  214197.0
# 11128002              34       45    19648             0.0  214198.0
# 11128003              34       45      969             0.0  214199.0
#
#           city_code  item_category_id  type_code  subtype_code  \
# 11127999         20                55         13             2
# 11128000         20                64         14            42
# 11128001         20                55         13             2
# 11128002         20                40         11             4
# 11128003         20                37         11             1
#
#           item_cnt_month_lag_1  item_cnt_month_lag_2  item_cnt_month_lag_3  \
# 11127999                   1.0                   0.0                   0.0
# 11128000                   0.0                   0.0                   NaN
# 11128001                   0.0                   0.0                   0.0
# 11128002                   0.0                   0.0                   0.0
# 11128003                   0.0                   0.0                   0.0
#
#           item_cnt_month_lag_6  item_cnt_month_lag_12  \
# 11127999                   0.0                    NaN
# 11128000                   NaN                    NaN
# 11128001                   0.0                    0.0
# 11128002                   0.0                    NaN
# 11128003                   0.0                    0.0
#
#           date_avg_item_cnt_lag_1  date_item_avg_item_cnt_lag_1  \
# 11127999                 0.258545                      0.045441
# 11128000                 0.258545                      0.022720
# 11128001                 0.258545                      0.113647
# 11128002                 0.258545                      0.045441
# 11128003                 0.258545                      0.068176
#
#           date_item_avg_item_cnt_lag_2  date_item_avg_item_cnt_lag_3  \
# 11127999                      0.023254                      0.071411
# 11128000                      0.069763                           NaN
# 11128001                      0.069763                      0.095215
# 11128002                      0.069763                      0.166626
# 11128003                      0.116272                      0.023804
#
#           date_item_avg_item_cnt_lag_6  date_item_avg_item_cnt_lag_12  \
# 11127999                      0.590820                            NaN
# 11128000                           NaN                            NaN
# 11128001                      0.250000                       0.180054
# 11128002                      0.090881                            NaN
# 11128003                      0.068176                       0.119995
#
#           date_shop_avg_item_cnt_lag_1  date_shop_avg_item_cnt_lag_2  \
# 11127999                      0.126709                      0.128784
# 11128000                      0.126709                      0.128784
# 11128001                      0.126709                      0.128784
# 11128002                      0.126709                      0.128784
# 11128003                      0.126709                      0.128784
#
#           date_shop_avg_item_cnt_lag_3  date_shop_avg_item_cnt_lag_6  \
# 11127999                      0.139038                      0.137573
# 11128000                           NaN                           NaN
# 11128001                      0.139038                      0.137573
# 11128002                      0.139038                      0.137573
# 11128003                      0.139038                      0.137573
#
#           date_shop_avg_item_cnt_lag_12  date_cat_avg_item_cnt_lag_1  \
# 11127999                            NaN                     0.196899
# 11128000                            NaN                     0.155884
# 11128001                       0.181274                     0.196899
# 11128002                            NaN                     0.220825
# 11128003                       0.181274                     0.256836
#
#           date_shop_cat_avg_item_cnt_lag_1  date_shop_type_avg_item_cnt_lag_1  \
# 11127999                          0.126831                           0.089294
# 11128000                          0.094482                           0.106201
# 11128001                          0.126831                           0.089294
# 11128002                          0.083740                           0.097046
# 11128003                          0.128174                           0.097046
#
#           date_shop_subtype_avg_item_cnt_lag_1  date_city_avg_item_cnt_lag_1  \
# 11127999                              0.126831                      0.135376
# 11128000                              0.094482                      0.135376
# 11128001                              0.126831                      0.135376
# 11128002                              0.083740                      0.135376
# 11128003                              0.126343                      0.135376
#
#           date_item_city_avg_item_cnt_lag_1  date_type_avg_item_cnt_lag_1  \
# 11127999                                0.5                      0.146973
# 11128000                                0.0                      0.237305
# 11128001                                0.0                      0.146973
# 11128002                                0.0                      0.224243
# 11128003                                0.5                      0.224243
#
#           date_subtype_avg_item_cnt_lag_1  item_avg_item_price
# 11127999                         0.196899              188.625
# 11128000                         0.155884             1257.000
# 11128001                         0.196899              198.125
# 11128002                         0.220825               98.125
# 11128003                         0.240967              502.250
# (11128004, 35)
#           date_block_num  shop_id  item_id  item_cnt_month        ID  \
# 11127999              34       45    18454             0.0  214195.0
# 11128000              34       45    16188             0.0  214196.0
# 11128001              34       45    15757             0.0  214197.0
# 11128002              34       45    19648             0.0  214198.0
# 11128003              34       45      969             0.0  214199.0
#
#           city_code  item_category_id  type_code  subtype_code  \
# 11127999         20                55         13             2
# 11128000         20                64         14            42
# 11128001         20                55         13             2
# 11128002         20                40         11             4
# 11128003         20                37         11             1
#
#           item_cnt_month_lag_1  item_cnt_month_lag_2  item_cnt_month_lag_3  \
# 11127999                   1.0                   0.0                   0.0
# 11128000                   0.0                   0.0                   NaN
# 11128001                   0.0                   0.0                   0.0
# 11128002                   0.0                   0.0                   0.0
# 11128003                   0.0                   0.0                   0.0
#
#           item_cnt_month_lag_6  item_cnt_month_lag_12  \
# 11127999                   0.0                    NaN
# 11128000                   NaN                    NaN
# 11128001                   0.0                    0.0
# 11128002                   0.0                    NaN
# 11128003                   0.0                    0.0
#
#           date_avg_item_cnt_lag_1  date_item_avg_item_cnt_lag_1  \
# 11127999                 0.258545                      0.045441
# 11128000                 0.258545                      0.022720
# 11128001                 0.258545                      0.113647
# 11128002                 0.258545                      0.045441
# 11128003                 0.258545                      0.068176
#
#           date_item_avg_item_cnt_lag_2  date_item_avg_item_cnt_lag_3  \
# 11127999                      0.023254                      0.071411
# 11128000                      0.069763                           NaN
# 11128001                      0.069763                      0.095215
# 11128002                      0.069763                      0.166626
# 11128003                      0.116272                      0.023804
#
#           date_item_avg_item_cnt_lag_6  date_item_avg_item_cnt_lag_12  \
# 11127999                      0.590820                            NaN
# 11128000                           NaN                            NaN
# 11128001                      0.250000                       0.180054
# 11128002                      0.090881                            NaN
# 11128003                      0.068176                       0.119995
#
#           date_shop_avg_item_cnt_lag_1  date_shop_avg_item_cnt_lag_2  \
# 11127999                      0.126709                      0.128784
# 11128000                      0.126709                      0.128784
# 11128001                      0.126709                      0.128784
# 11128002                      0.126709                      0.128784
# 11128003                      0.126709                      0.128784
#
#           date_shop_avg_item_cnt_lag_3  date_shop_avg_item_cnt_lag_6  \
# 11127999                      0.139038                      0.137573
# 11128000                           NaN                           NaN
# 11128001                      0.139038                      0.137573
# 11128002                      0.139038                      0.137573
# 11128003                      0.139038                      0.137573
#
#           date_shop_avg_item_cnt_lag_12  date_cat_avg_item_cnt_lag_1  \
# 11127999                            NaN                     0.196899
# 11128000                            NaN                     0.155884
# 11128001                       0.181274                     0.196899
# 11128002                            NaN                     0.220825
# 11128003                       0.181274                     0.256836
#
#           date_shop_cat_avg_item_cnt_lag_1  date_shop_type_avg_item_cnt_lag_1  \
# 11127999                          0.126831                           0.089294
# 11128000                          0.094482                           0.106201
# 11128001                          0.126831                           0.089294
# 11128002                          0.083740                           0.097046
# 11128003                          0.128174                           0.097046
#
#           date_shop_subtype_avg_item_cnt_lag_1  date_city_avg_item_cnt_lag_1  \
# 11127999                              0.126831                      0.135376
# 11128000                              0.094482                      0.135376
# 11128001                              0.126831                      0.135376
# 11128002                              0.083740                      0.135376
# 11128003                              0.126343                      0.135376
#
#           date_item_city_avg_item_cnt_lag_1  date_type_avg_item_cnt_lag_1  \
# 11127999                                0.5                      0.146973
# 11128000                                0.0                      0.237305
# 11128001                                0.0                      0.146973
# 11128002                                0.0                      0.224243
# 11128003                                0.5                      0.224243
#
#           date_subtype_avg_item_cnt_lag_1  item_avg_item_price  \
# 11127999                         0.196899              188.625
# 11128000                         0.155884             1257.000
# 11128001                         0.196899              198.125
# 11128002                         0.220825               98.125
# 11128003                         0.240967              502.250
#
#           date_item_avg_item_price
# 11127999                       NaN
# 11128000                       NaN
# 11128001                       NaN
# 11128002                       NaN
# 11128003                       NaN
# (11128004, 48)
#           date_block_num  shop_id  item_id  item_cnt_month        ID  \
# 11127999              34       45    18454             0.0  214195.0
# 11128000              34       45    16188             0.0  214196.0
# 11128001              34       45    15757             0.0  214197.0
# 11128002              34       45    19648             0.0  214198.0
# 11128003              34       45      969             0.0  214199.0
#
#           city_code  item_category_id  type_code  subtype_code  \
# 11127999         20                55         13             2
# 11128000         20                64         14            42
# 11128001         20                55         13             2
# 11128002         20                40         11             4
# 11128003         20                37         11             1
#
#           item_cnt_month_lag_1  item_cnt_month_lag_2  item_cnt_month_lag_3  \
# 11127999                   1.0                   0.0                   0.0
# 11128000                   0.0                   0.0                   NaN
# 11128001                   0.0                   0.0                   0.0
# 11128002                   0.0                   0.0                   0.0
# 11128003                   0.0                   0.0                   0.0
#
#           item_cnt_month_lag_6  item_cnt_month_lag_12  \
# 11127999                   0.0                    NaN
# 11128000                   NaN                    NaN
# 11128001                   0.0                    0.0
# 11128002                   0.0                    NaN
# 11128003                   0.0                    0.0
#
#           date_avg_item_cnt_lag_1  date_item_avg_item_cnt_lag_1  \
# 11127999                 0.258545                      0.045441
# 11128000                 0.258545                      0.022720
# 11128001                 0.258545                      0.113647
# 11128002                 0.258545                      0.045441
# 11128003                 0.258545                      0.068176
#
#           date_item_avg_item_cnt_lag_2  date_item_avg_item_cnt_lag_3  \
# 11127999                      0.023254                      0.071411
# 11128000                      0.069763                           NaN
# 11128001                      0.069763                      0.095215
# 11128002                      0.069763                      0.166626
# 11128003                      0.116272                      0.023804
#
#           date_item_avg_item_cnt_lag_6  date_item_avg_item_cnt_lag_12  \
# 11127999                      0.590820                            NaN
# 11128000                           NaN                            NaN
# 11128001                      0.250000                       0.180054
# 11128002                      0.090881                            NaN
# 11128003                      0.068176                       0.119995
#
#           date_shop_avg_item_cnt_lag_1  date_shop_avg_item_cnt_lag_2  \
# 11127999                      0.126709                      0.128784
# 11128000                      0.126709                      0.128784
# 11128001                      0.126709                      0.128784
# 11128002                      0.126709                      0.128784
# 11128003                      0.126709                      0.128784
#
#           date_shop_avg_item_cnt_lag_3  date_shop_avg_item_cnt_lag_6  \
# 11127999                      0.139038                      0.137573
# 11128000                           NaN                           NaN
# 11128001                      0.139038                      0.137573
# 11128002                      0.139038                      0.137573
# 11128003                      0.139038                      0.137573
#
#           date_shop_avg_item_cnt_lag_12  date_cat_avg_item_cnt_lag_1  \
# 11127999                            NaN                     0.196899
# 11128000                            NaN                     0.155884
# 11128001                       0.181274                     0.196899
# 11128002                            NaN                     0.220825
# 11128003                       0.181274                     0.256836
#
#           date_shop_cat_avg_item_cnt_lag_1  date_shop_type_avg_item_cnt_lag_1  \
# 11127999                          0.126831                           0.089294
# 11128000                          0.094482                           0.106201
# 11128001                          0.126831                           0.089294
# 11128002                          0.083740                           0.097046
# 11128003                          0.128174                           0.097046
#
#           date_shop_subtype_avg_item_cnt_lag_1  date_city_avg_item_cnt_lag_1  \
# 11127999                              0.126831                      0.135376
# 11128000                              0.094482                      0.135376
# 11128001                              0.126831                      0.135376
# 11128002                              0.083740                      0.135376
# 11128003                              0.126343                      0.135376
#
#           date_item_city_avg_item_cnt_lag_1  date_type_avg_item_cnt_lag_1  \
# 11127999                                0.5                      0.146973
# 11128000                                0.0                      0.237305
# 11128001                                0.0                      0.146973
# 11128002                                0.0                      0.224243
# 11128003                                0.5                      0.224243
#
#           date_subtype_avg_item_cnt_lag_1  item_avg_item_price  \
# 11127999                         0.196899              188.625
# 11128000                         0.155884             1257.000
# 11128001                         0.196899              198.125
# 11128002                         0.220825               98.125
# 11128003                         0.240967              502.250
#
#           date_item_avg_item_price  date_item_avg_item_price_lag_1  \
# 11127999                       NaN                          99.000
# 11128000                       NaN                        1359.000
# 11128001                       NaN                         229.000
# 11128002                       NaN                          89.125
# 11128003                       NaN                         198.000
#
#           date_item_avg_item_price_lag_2  date_item_avg_item_price_lag_3  \
# 11127999                            99.0                          99.000
# 11128000                          1223.0                             NaN
# 11128001                           229.0                         229.000
# 11128002                            99.0                          94.875
# 11128003                           198.0                         198.000
#
#           date_item_avg_item_price_lag_4  date_item_avg_item_price_lag_5  \
# 11127999                            99.0                         98.9375
# 11128000                             NaN                             NaN
# 11128001                           229.0                        229.0000
# 11128002                            99.0                         99.0000
# 11128003                           198.0                        242.0000
#
#           date_item_avg_item_price_lag_6  delta_price_lag_1  \
# 11127999                         199.000          -0.475098
# 11128000                             NaN           0.081116
# 11128001                         208.125           0.155884
# 11128002                          99.000          -0.091736
# 11128003                         248.000          -0.605957
#
#           delta_price_lag_2  delta_price_lag_3  delta_price_lag_4  \
# 11127999          -0.475098          -0.475098          -0.475098
# 11128000          -0.027054                NaN                NaN
# 11128001           0.155884           0.155884           0.155884
# 11128002           0.008919          -0.033112           0.008919
# 11128003          -0.605957          -0.605957          -0.605957
#
#           delta_price_lag_5  delta_price_lag_6  delta_price_lag
# 11127999          -0.475586           0.054993        -0.475098
# 11128000                NaN                NaN         0.081116
# 11128001           0.155884           0.050476         0.155884
# 11128002           0.008919           0.008919        -0.091736
# 11128003          -0.518066          -0.506348        -0.605957
# (11128004, 34)
#           date_block_num  shop_id  item_id  item_cnt_month        ID  \
# 11127999              34       45    18454             0.0  214195.0
# 11128000              34       45    16188             0.0  214196.0
# 11128001              34       45    15757             0.0  214197.0
# 11128002              34       45    19648             0.0  214198.0
# 11128003              34       45      969             0.0  214199.0
#
#           city_code  item_category_id  type_code  subtype_code  \
# 11127999         20                55         13             2
# 11128000         20                64         14            42
# 11128001         20                55         13             2
# 11128002         20                40         11             4
# 11128003         20                37         11             1
#
#           item_cnt_month_lag_1  item_cnt_month_lag_2  item_cnt_month_lag_3  \
# 11127999                   1.0                   0.0                   0.0
# 11128000                   0.0                   0.0                   NaN
# 11128001                   0.0                   0.0                   0.0
# 11128002                   0.0                   0.0                   0.0
# 11128003                   0.0                   0.0                   0.0
#
#           item_cnt_month_lag_6  item_cnt_month_lag_12  \
# 11127999                   0.0                    NaN
# 11128000                   NaN                    NaN
# 11128001                   0.0                    0.0
# 11128002                   0.0                    NaN
# 11128003                   0.0                    0.0
#
#           date_avg_item_cnt_lag_1  date_item_avg_item_cnt_lag_1  \
# 11127999                 0.258545                      0.045441
# 11128000                 0.258545                      0.022720
# 11128001                 0.258545                      0.113647
# 11128002                 0.258545                      0.045441
# 11128003                 0.258545                      0.068176
#
#           date_item_avg_item_cnt_lag_2  date_item_avg_item_cnt_lag_3  \
# 11127999                      0.023254                      0.071411
# 11128000                      0.069763                           NaN
# 11128001                      0.069763                      0.095215
# 11128002                      0.069763                      0.166626
# 11128003                      0.116272                      0.023804
#
#           date_item_avg_item_cnt_lag_6  date_item_avg_item_cnt_lag_12  \
# 11127999                      0.590820                            NaN
# 11128000                           NaN                            NaN
# 11128001                      0.250000                       0.180054
# 11128002                      0.090881                            NaN
# 11128003                      0.068176                       0.119995
#
#           date_shop_avg_item_cnt_lag_1  date_shop_avg_item_cnt_lag_2  \
# 11127999                      0.126709                      0.128784
# 11128000                      0.126709                      0.128784
# 11128001                      0.126709                      0.128784
# 11128002                      0.126709                      0.128784
# 11128003                      0.126709                      0.128784
#
#           date_shop_avg_item_cnt_lag_3  date_shop_avg_item_cnt_lag_6  \
# 11127999                      0.139038                      0.137573
# 11128000                           NaN                           NaN
# 11128001                      0.139038                      0.137573
# 11128002                      0.139038                      0.137573
# 11128003                      0.139038                      0.137573
#
#           date_shop_avg_item_cnt_lag_12  date_cat_avg_item_cnt_lag_1  \
# 11127999                            NaN                     0.196899
# 11128000                            NaN                     0.155884
# 11128001                       0.181274                     0.196899
# 11128002                            NaN                     0.220825
# 11128003                       0.181274                     0.256836
#
#           date_shop_cat_avg_item_cnt_lag_1  date_shop_type_avg_item_cnt_lag_1  \
# 11127999                          0.126831                           0.089294
# 11128000                          0.094482                           0.106201
# 11128001                          0.126831                           0.089294
# 11128002                          0.083740                           0.097046
# 11128003                          0.128174                           0.097046
#
#           date_shop_subtype_avg_item_cnt_lag_1  date_city_avg_item_cnt_lag_1  \
# 11127999                              0.126831                      0.135376
# 11128000                              0.094482                      0.135376
# 11128001                              0.126831                      0.135376
# 11128002                              0.083740                      0.135376
# 11128003                              0.126343                      0.135376
#
#           date_item_city_avg_item_cnt_lag_1  date_type_avg_item_cnt_lag_1  \
# 11127999                                0.5                      0.146973
# 11128000                                0.0                      0.237305
# 11128001                                0.0                      0.146973
# 11128002                                0.0                      0.224243
# 11128003                                0.5                      0.224243
#
#           date_subtype_avg_item_cnt_lag_1  delta_price_lag
# 11127999                         0.196899        -0.475098
# 11128000                         0.155884         0.081116
# 11128001                         0.196899         0.155884
# 11128002                         0.220825        -0.091736
# 11128003                         0.240967        -0.605957
# 299.97033286094666

# %% [markdown]
# Last month shop revenue trend

# %%
ts = time.time()
group = train.groupby(['date_block_num','shop_id']).agg({'revenue': ['sum']})
group.columns = ['date_shop_revenue']
group.reset_index(inplace=True)

matrix = pd.merge(matrix, group, on=['date_block_num','shop_id'], how='left')
matrix['date_shop_revenue'] = matrix['date_shop_revenue'].astype(np.float32)
matrix.shape
matrix.tail()

group = group.groupby(['shop_id']).agg({'date_shop_revenue': ['mean']})
group.columns = ['shop_avg_revenue']
group.reset_index(inplace=True)

matrix = pd.merge(matrix, group, on=['shop_id'], how='left')
matrix['shop_avg_revenue'] = matrix['shop_avg_revenue'].astype(np.float32)

matrix['delta_revenue'] = (matrix['date_shop_revenue'] - matrix['shop_avg_revenue']) / matrix['shop_avg_revenue']
matrix['delta_revenue'] = matrix['delta_revenue'].astype(np.float16)

matrix = lag_feature(matrix, [1], 'delta_revenue')

matrix.drop(['date_shop_revenue','shop_avg_revenue','delta_revenue'], axis=1, inplace=True)
matrix.shape
matrix.tail()
time.time() - ts
# Out:
# (11128004, 35)
#           date_block_num  shop_id  item_id  item_cnt_month        ID  \
# 11127999              34       45    18454             0.0  214195.0
# 11128000              34       45    16188             0.0  214196.0
# 11128001              34       45    15757             0.0  214197.0
# 11128002              34       45    19648             0.0  214198.0
# 11128003              34       45      969             0.0  214199.0
#
#           city_code  item_category_id  type_code  subtype_code  \
# 11127999         20                55         13             2
# 11128000         20                64         14            42
# 11128001         20                55         13             2
# 11128002         20                40         11             4
# 11128003         20                37         11             1
#
#           item_cnt_month_lag_1  item_cnt_month_lag_2  item_cnt_month_lag_3  \
# 11127999                   1.0                   0.0                   0.0
# 11128000                   0.0                   0.0                   NaN
# 11128001                   0.0                   0.0                   0.0
# 11128002                   0.0                   0.0                   0.0
# 11128003                   0.0                   0.0                   0.0
#
#           item_cnt_month_lag_6  item_cnt_month_lag_12  \
# 11127999                   0.0                    NaN
# 11128000                   NaN                    NaN
# 11128001                   0.0                    0.0
# 11128002                   0.0                    NaN
# 11128003                   0.0                    0.0
#
#           date_avg_item_cnt_lag_1  date_item_avg_item_cnt_lag_1  \
# 11127999                 0.258545                      0.045441
# 11128000                 0.258545                      0.022720
# 11128001                 0.258545                      0.113647
# 11128002                 0.258545                      0.045441
# 11128003                 0.258545                      0.068176
#
#           date_item_avg_item_cnt_lag_2  date_item_avg_item_cnt_lag_3  \
# 11127999                      0.023254                      0.071411
# 11128000                      0.069763                           NaN
# 11128001                      0.069763                      0.095215
# 11128002                      0.069763                      0.166626
# 11128003                      0.116272                      0.023804
#
#           date_item_avg_item_cnt_lag_6  date_item_avg_item_cnt_lag_12  \
# 11127999                      0.590820                            NaN
# 11128000                           NaN                            NaN
# 11128001                      0.250000                       0.180054
# 11128002                      0.090881                            NaN
# 11128003                      0.068176                       0.119995
#
#           date_shop_avg_item_cnt_lag_1  date_shop_avg_item_cnt_lag_2  \
# 11127999                      0.126709                      0.128784
# 11128000                      0.126709                      0.128784
# 11128001                      0.126709                      0.128784
# 11128002                      0.126709                      0.128784
# 11128003                      0.126709                      0.128784
#
#           date_shop_avg_item_cnt_lag_3  date_shop_avg_item_cnt_lag_6  \
# 11127999                      0.139038                      0.137573
# 11128000                           NaN                           NaN
# 11128001                      0.139038                      0.137573
# 11128002                      0.139038                      0.137573
# 11128003                      0.139038                      0.137573
#
#           date_shop_avg_item_cnt_lag_12  date_cat_avg_item_cnt_lag_1  \
# 11127999                            NaN                     0.196899
# 11128000                            NaN                     0.155884
# 11128001                       0.181274                     0.196899
# 11128002                            NaN                     0.220825
# 11128003                       0.181274                     0.256836
#
#           date_shop_cat_avg_item_cnt_lag_1  date_shop_type_avg_item_cnt_lag_1  \
# 11127999                          0.126831                           0.089294
# 11128000                          0.094482                           0.106201
# 11128001                          0.126831                           0.089294
# 11128002                          0.083740                           0.097046
# 11128003                          0.128174                           0.097046
#
#           date_shop_subtype_avg_item_cnt_lag_1  date_city_avg_item_cnt_lag_1  \
# 11127999                              0.126831                      0.135376
# 11128000                              0.094482                      0.135376
# 11128001                              0.126831                      0.135376
# 11128002                              0.083740                      0.135376
# 11128003                              0.126343                      0.135376
#
#           date_item_city_avg_item_cnt_lag_1  date_type_avg_item_cnt_lag_1  \
# 11127999                                0.5                      0.146973
# 11128000                                0.0                      0.237305
# 11128001                                0.0                      0.146973
# 11128002                                0.0                      0.224243
# 11128003                                0.5                      0.224243
#
#           date_subtype_avg_item_cnt_lag_1  delta_price_lag  date_shop_revenue
# 11127999                         0.196899        -0.475098                NaN
# 11128000                         0.155884         0.081116                NaN
# 11128001                         0.196899         0.155884                NaN
# 11128002                         0.220825        -0.091736                NaN
# 11128003                         0.240967        -0.605957                NaN
# (11128004, 35)
#           date_block_num  shop_id  item_id  item_cnt_month        ID  \
# 11127999              34       45    18454             0.0  214195.0
# 11128000              34       45    16188             0.0  214196.0
# 11128001              34       45    15757             0.0  214197.0
# 11128002              34       45    19648             0.0  214198.0
# 11128003              34       45      969             0.0  214199.0
#
#           city_code  item_category_id  type_code  subtype_code  \
# 11127999         20                55         13             2
# 11128000         20                64         14            42
# 11128001         20                55         13             2
# 11128002         20                40         11             4
# 11128003         20                37         11             1
#
#           item_cnt_month_lag_1  item_cnt_month_lag_2  item_cnt_month_lag_3  \
# 11127999                   1.0                   0.0                   0.0
# 11128000                   0.0                   0.0                   NaN
# 11128001                   0.0                   0.0                   0.0
# 11128002                   0.0                   0.0                   0.0
# 11128003                   0.0                   0.0                   0.0
#
#           item_cnt_month_lag_6  item_cnt_month_lag_12  \
# 11127999                   0.0                    NaN
# 11128000                   NaN                    NaN
# 11128001                   0.0                    0.0
# 11128002                   0.0                    NaN
# 11128003                   0.0                    0.0
#
#           date_avg_item_cnt_lag_1  date_item_avg_item_cnt_lag_1  \
# 11127999                 0.258545                      0.045441
# 11128000                 0.258545                      0.022720
# 11128001                 0.258545                      0.113647
# 11128002                 0.258545                      0.045441
# 11128003                 0.258545                      0.068176
#
#           date_item_avg_item_cnt_lag_2  date_item_avg_item_cnt_lag_3  \
# 11127999                      0.023254                      0.071411
# 11128000                      0.069763                           NaN
# 11128001                      0.069763                      0.095215
# 11128002                      0.069763                      0.166626
# 11128003                      0.116272                      0.023804
#
#           date_item_avg_item_cnt_lag_6  date_item_avg_item_cnt_lag_12  \
# 11127999                      0.590820                            NaN
# 11128000                           NaN                            NaN
# 11128001                      0.250000                       0.180054
# 11128002                      0.090881                            NaN
# 11128003                      0.068176                       0.119995
#
#           date_shop_avg_item_cnt_lag_1  date_shop_avg_item_cnt_lag_2  \
# 11127999                      0.126709                      0.128784
# 11128000                      0.126709                      0.128784
# 11128001                      0.126709                      0.128784
# 11128002                      0.126709                      0.128784
# 11128003                      0.126709                      0.128784
#
#           date_shop_avg_item_cnt_lag_3  date_shop_avg_item_cnt_lag_6  \
# 11127999                      0.139038                      0.137573
# 11128000                           NaN                           NaN
# 11128001                      0.139038                      0.137573
# 11128002                      0.139038                      0.137573
# 11128003                      0.139038                      0.137573
#
#           date_shop_avg_item_cnt_lag_12  date_cat_avg_item_cnt_lag_1  \
# 11127999                            NaN                     0.196899
# 11128000                            NaN                     0.155884
# 11128001                       0.181274                     0.196899
# 11128002                            NaN                     0.220825
# 11128003                       0.181274                     0.256836
#
#           date_shop_cat_avg_item_cnt_lag_1  date_shop_type_avg_item_cnt_lag_1  \
# 11127999                          0.126831                           0.089294
# 11128000                          0.094482                           0.106201
# 11128001                          0.126831                           0.089294
# 11128002                          0.083740                           0.097046
# 11128003                          0.128174                           0.097046
#
#           date_shop_subtype_avg_item_cnt_lag_1  date_city_avg_item_cnt_lag_1  \
# 11127999                              0.126831                      0.135376
# 11128000                              0.094482                      0.135376
# 11128001                              0.126831                      0.135376
# 11128002                              0.083740                      0.135376
# 11128003                              0.126343                      0.135376
#
#           date_item_city_avg_item_cnt_lag_1  date_type_avg_item_cnt_lag_1  \
# 11127999                                0.5                      0.146973
# 11128000                                0.0                      0.237305
# 11128001                                0.0                      0.146973
# 11128002                                0.0                      0.224243
# 11128003                                0.5                      0.224243
#
#           date_subtype_avg_item_cnt_lag_1  delta_price_lag  \
# 11127999                         0.196899        -0.475098
# 11128000                         0.155884         0.081116
# 11128001                         0.196899         0.155884
# 11128002                         0.220825        -0.091736
# 11128003                         0.240967        -0.605957
#
#           delta_revenue_lag_1
# 11127999            -0.290039
# 11128000            -0.290039
# 11128001            -0.290039
# 11128002            -0.290039
# 11128003            -0.290039
# 17.063099145889282

# %% [markdown]
# ## Special features

# %%
matrix['month'] = matrix['date_block_num'] % 12

# %% [markdown]
# Number of days in a month. There are no leap years.

# %%
days = pd.Series([31,28,31,30,31,30,31,31,30,31,30,31])
matrix['days'] = matrix['month'].map(days).astype(np.int8)

# %% [markdown]
# Months since the last sale for each shop/item pair and for item only. I use programing approach.
#
# <i>Create HashTable with key equals to {shop_id,item_id} and value equals to date_block_num. Iterate data from the top. Foreach row if {row.shop_id,row.item_id} is not present in the table, then add it to the table and set its value to row.date_block_num. if HashTable contains key, then calculate the difference beteween cached value and row.date_block_num.</i>

# %%
ts = time.time()
cache = {}
matrix['item_shop_last_sale'] = -1
matrix['item_shop_last_sale'] = matrix['item_shop_last_sale'].astype(np.int8)
for idx, row in matrix.iterrows():    
    key = str(row.item_id)+' '+str(row.shop_id)
    if key not in cache:
        if row.item_cnt_month!=0:
            cache[key] = row.date_block_num
    else:
        last_date_block_num = cache[key]
        matrix.at[idx, 'item_shop_last_sale'] = row.date_block_num - last_date_block_num
        cache[key] = row.date_block_num         
time.time() - ts
matrix.shape
matrix.tail()
# Out:
# 1096.0255110263824
# (11128004, 38)
#           date_block_num  shop_id  item_id  item_cnt_month        ID  \
# 11127999              34       45    18454             0.0  214195.0
# 11128000              34       45    16188             0.0  214196.0
# 11128001              34       45    15757             0.0  214197.0
# 11128002              34       45    19648             0.0  214198.0
# 11128003              34       45      969             0.0  214199.0
#
#           city_code  item_category_id  type_code  subtype_code  \
# 11127999         20                55         13             2
# 11128000         20                64         14            42
# 11128001         20                55         13             2
# 11128002         20                40         11             4
# 11128003         20                37         11             1
#
#           item_cnt_month_lag_1  item_cnt_month_lag_2  item_cnt_month_lag_3  \
# 11127999                   1.0                   0.0                   0.0
# 11128000                   0.0                   0.0                   NaN
# 11128001                   0.0                   0.0                   0.0
# 11128002                   0.0                   0.0                   0.0
# 11128003                   0.0                   0.0                   0.0
#
#           item_cnt_month_lag_6  item_cnt_month_lag_12  \
# 11127999                   0.0                    NaN
# 11128000                   NaN                    NaN
# 11128001                   0.0                    0.0
# 11128002                   0.0                    NaN
# 11128003                   0.0                    0.0
#
#           date_avg_item_cnt_lag_1  date_item_avg_item_cnt_lag_1  \
# 11127999                 0.258545                      0.045441
# 11128000                 0.258545                      0.022720
# 11128001                 0.258545                      0.113647
# 11128002                 0.258545                      0.045441
# 11128003                 0.258545                      0.068176
#
#           date_item_avg_item_cnt_lag_2  date_item_avg_item_cnt_lag_3  \
# 11127999                      0.023254                      0.071411
# 11128000                      0.069763                           NaN
# 11128001                      0.069763                      0.095215
# 11128002                      0.069763                      0.166626
# 11128003                      0.116272                      0.023804
#
#           date_item_avg_item_cnt_lag_6  date_item_avg_item_cnt_lag_12  \
# 11127999                      0.590820                            NaN
# 11128000                           NaN                            NaN
# 11128001                      0.250000                       0.180054
# 11128002                      0.090881                            NaN
# 11128003                      0.068176                       0.119995
#
#           date_shop_avg_item_cnt_lag_1  date_shop_avg_item_cnt_lag_2  \
# 11127999                      0.126709                      0.128784
# 11128000                      0.126709                      0.128784
# 11128001                      0.126709                      0.128784
# 11128002                      0.126709                      0.128784
# 11128003                      0.126709                      0.128784
#
#           date_shop_avg_item_cnt_lag_3  date_shop_avg_item_cnt_lag_6  \
# 11127999                      0.139038                      0.137573
# 11128000                           NaN                           NaN
# 11128001                      0.139038                      0.137573
# 11128002                      0.139038                      0.137573
# 11128003                      0.139038                      0.137573
#
#           date_shop_avg_item_cnt_lag_12  date_cat_avg_item_cnt_lag_1  \
# 11127999                            NaN                     0.196899
# 11128000                            NaN                     0.155884
# 11128001                       0.181274                     0.196899
# 11128002                            NaN                     0.220825
# 11128003                       0.181274                     0.256836
#
#           date_shop_cat_avg_item_cnt_lag_1  date_shop_type_avg_item_cnt_lag_1  \
# 11127999                          0.126831                           0.089294
# 11128000                          0.094482                           0.106201
# 11128001                          0.126831                           0.089294
# 11128002                          0.083740                           0.097046
# 11128003                          0.128174                           0.097046
#
#           date_shop_subtype_avg_item_cnt_lag_1  date_city_avg_item_cnt_lag_1  \
# 11127999                              0.126831                      0.135376
# 11128000                              0.094482                      0.135376
# 11128001                              0.126831                      0.135376
# 11128002                              0.083740                      0.135376
# 11128003                              0.126343                      0.135376
#
#           date_item_city_avg_item_cnt_lag_1  date_type_avg_item_cnt_lag_1  \
# 11127999                                0.5                      0.146973
# 11128000                                0.0                      0.237305
# 11128001                                0.0                      0.146973
# 11128002                                0.0                      0.224243
# 11128003                                0.5                      0.224243
#
#           date_subtype_avg_item_cnt_lag_1  delta_price_lag  \
# 11127999                         0.196899        -0.475098
# 11128000                         0.155884         0.081116
# 11128001                         0.196899         0.155884
# 11128002                         0.220825        -0.091736
# 11128003                         0.240967        -0.605957
#
#           delta_revenue_lag_1  month  days  item_shop_last_sale
# 11127999            -0.290039     10    30                    1
# 11128000            -0.290039     10    30                   -1
# 11128001            -0.290039     10    30                    1
# 11128002            -0.290039     10    30                   -1
# 11128003            -0.290039     10    30                    1

# %%
ts = time.time()
cache = {}
matrix['item_last_sale'] = -1
matrix['item_last_sale'] = matrix['item_last_sale'].astype(np.int8)
for idx, row in matrix.iterrows():    
    key = row.item_id
    if key not in cache:
        if row.item_cnt_month!=0:
            cache[key] = row.date_block_num
    else:
        last_date_block_num = cache[key]
        if row.date_block_num>last_date_block_num:
            matrix.at[idx, 'item_last_sale'] = row.date_block_num - last_date_block_num
            cache[key] = row.date_block_num         
time.time() - ts
matrix.shape
matrix.tail()
# Out:
# 745.8551528453827
# (11128004, 39)
#           date_block_num  shop_id  item_id  item_cnt_month        ID  \
# 11127999              34       45    18454             0.0  214195.0
# 11128000              34       45    16188             0.0  214196.0
# 11128001              34       45    15757             0.0  214197.0
# 11128002              34       45    19648             0.0  214198.0
# 11128003              34       45      969             0.0  214199.0
#
#           city_code  item_category_id  type_code  subtype_code  \
# 11127999         20                55         13             2
# 11128000         20                64         14            42
# 11128001         20                55         13             2
# 11128002         20                40         11             4
# 11128003         20                37         11             1
#
#           item_cnt_month_lag_1  item_cnt_month_lag_2  item_cnt_month_lag_3  \
# 11127999                   1.0                   0.0                   0.0
# 11128000                   0.0                   0.0                   NaN
# 11128001                   0.0                   0.0                   0.0
# 11128002                   0.0                   0.0                   0.0
# 11128003                   0.0                   0.0                   0.0
#
#           item_cnt_month_lag_6  item_cnt_month_lag_12  \
# 11127999                   0.0                    NaN
# 11128000                   NaN                    NaN
# 11128001                   0.0                    0.0
# 11128002                   0.0                    NaN
# 11128003                   0.0                    0.0
#
#           date_avg_item_cnt_lag_1  date_item_avg_item_cnt_lag_1  \
# 11127999                 0.258545                      0.045441
# 11128000                 0.258545                      0.022720
# 11128001                 0.258545                      0.113647
# 11128002                 0.258545                      0.045441
# 11128003                 0.258545                      0.068176
#
#           date_item_avg_item_cnt_lag_2  date_item_avg_item_cnt_lag_3  \
# 11127999                      0.023254                      0.071411
# 11128000                      0.069763                           NaN
# 11128001                      0.069763                      0.095215
# 11128002                      0.069763                      0.166626
# 11128003                      0.116272                      0.023804
#
#           date_item_avg_item_cnt_lag_6  date_item_avg_item_cnt_lag_12  \
# 11127999                      0.590820                            NaN
# 11128000                           NaN                            NaN
# 11128001                      0.250000                       0.180054
# 11128002                      0.090881                            NaN
# 11128003                      0.068176                       0.119995
#
#           date_shop_avg_item_cnt_lag_1  date_shop_avg_item_cnt_lag_2  \
# 11127999                      0.126709                      0.128784
# 11128000                      0.126709                      0.128784
# 11128001                      0.126709                      0.128784
# 11128002                      0.126709                      0.128784
# 11128003                      0.126709                      0.128784
#
#           date_shop_avg_item_cnt_lag_3  date_shop_avg_item_cnt_lag_6  \
# 11127999                      0.139038                      0.137573
# 11128000                           NaN                           NaN
# 11128001                      0.139038                      0.137573
# 11128002                      0.139038                      0.137573
# 11128003                      0.139038                      0.137573
#
#           date_shop_avg_item_cnt_lag_12  date_cat_avg_item_cnt_lag_1  \
# 11127999                            NaN                     0.196899
# 11128000                            NaN                     0.155884
# 11128001                       0.181274                     0.196899
# 11128002                            NaN                     0.220825
# 11128003                       0.181274                     0.256836
#
#           date_shop_cat_avg_item_cnt_lag_1  date_shop_type_avg_item_cnt_lag_1  \
# 11127999                          0.126831                           0.089294
# 11128000                          0.094482                           0.106201
# 11128001                          0.126831                           0.089294
# 11128002                          0.083740                           0.097046
# 11128003                          0.128174                           0.097046
#
#           date_shop_subtype_avg_item_cnt_lag_1  date_city_avg_item_cnt_lag_1  \
# 11127999                              0.126831                      0.135376
# 11128000                              0.094482                      0.135376
# 11128001                              0.126831                      0.135376
# 11128002                              0.083740                      0.135376
# 11128003                              0.126343                      0.135376
#
#           date_item_city_avg_item_cnt_lag_1  date_type_avg_item_cnt_lag_1  \
# 11127999                                0.5                      0.146973
# 11128000                                0.0                      0.237305
# 11128001                                0.0                      0.146973
# 11128002                                0.0                      0.224243
# 11128003                                0.5                      0.224243
#
#           date_subtype_avg_item_cnt_lag_1  delta_price_lag  \
# 11127999                         0.196899        -0.475098
# 11128000                         0.155884         0.081116
# 11128001                         0.196899         0.155884
# 11128002                         0.220825        -0.091736
# 11128003                         0.240967        -0.605957
#
#           delta_revenue_lag_1  month  days  item_shop_last_sale  \
# 11127999            -0.290039     10    30                    1
# 11128000            -0.290039     10    30                   -1
# 11128001            -0.290039     10    30                    1
# 11128002            -0.290039     10    30                   -1
# 11128003            -0.290039     10    30                    1
#
#           item_last_sale
# 11127999              -1
# 11128000              -1
# 11128001              -1
# 11128002              -1
# 11128003              -1

# %% [markdown]
# Months since the first sale for each shop/item pair and for item only.

# %%
ts = time.time()
matrix['item_shop_first_sale'] = matrix['date_block_num'] - matrix.groupby(['item_id','shop_id'])['date_block_num'].transform('min')
matrix['item_first_sale'] = matrix['date_block_num'] - matrix.groupby('item_id')['date_block_num'].transform('min')
time.time() - ts
# Out:
# 1.6127688884735107

# %%
matrix.to_csv('FinalData.csv')

# %% [markdown]
# ## Final preparations
# Because of the using 12 as lag value drop first 12 months. Also drop all the columns with this month calculated values (other words which can not be calcucated for the test set).

# %%
ts = time.time()
matrix = matrix[matrix.date_block_num > 11]
time.time() - ts
# Out:
# 0.8801600933074951

# %% [markdown]
# Producing lags brings a lot of nulls.

# %%
ts = time.time()
def fill_na(df):
    for col in df.columns:
        if ('_lag_' in col) & (df[col].isnull().any()):
            if ('item_cnt' in col):
                df[col].fillna(0, inplace=True)         
    return df

matrix = fill_na(matrix)
time.time() - ts
# Out:
# 5.354390621185303

# %%
matrix.columns
# Out:
# Index(['date_block_num', 'shop_id', 'item_id', 'item_cnt_month', 'ID',
#        'city_code', 'item_category_id', 'type_code', 'subtype_code',
#        'item_cnt_month_lag_1', 'item_cnt_month_lag_2', 'item_cnt_month_lag_3',
#        'item_cnt_month_lag_6', 'item_cnt_month_lag_12',
#        'date_avg_item_cnt_lag_1', 'date_item_avg_item_cnt_lag_1',
#        'date_item_avg_item_cnt_lag_2', 'date_item_avg_item_cnt_lag_3',
#        'date_item_avg_item_cnt_lag_6', 'date_item_avg_item_cnt_lag_12',
#        'date_shop_avg_item_cnt_lag_1', 'date_shop_avg_item_cnt_lag_2',
#        'date_shop_avg_item_cnt_lag_3', 'date_shop_avg_item_cnt_lag_6',
#        'date_shop_avg_item_cnt_lag_12', 'date_cat_avg_item_cnt_lag_1',
#        'date_shop_cat_avg_item_cnt_lag_1', 'date_shop_type_avg_item_cnt_lag_1',
#        'date_shop_subtype_avg_item_cnt_lag_1', 'date_city_avg_item_cnt_lag_1',
#        'date_item_city_avg_item_cnt_lag_1', 'date_type_avg_item_cnt_lag_1',
#        'date_subtype_avg_item_cnt_lag_1', 'delta_price_lag',
#        'delta_revenue_lag_1', 'month', 'days', 'item_shop_last_sale',
#        'item_last_sale', 'item_shop_first_sale', 'item_first_sale'],
#       dtype='object')

# %%
matrix.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6639294 entries, 4488710 to 11128003
# Data columns (total 41 columns):
# date_block_num                          int8
# shop_id                                 int8
# item_id                                 int16
# item_cnt_month                          float16
# ID                                      float64
# city_code                               int8
# item_category_id                        int8
# type_code                               int8
# subtype_code                            int8
# item_cnt_month_lag_1                    float16
# item_cnt_month_lag_2                    float16
# item_cnt_month_lag_3                    float16
# item_cnt_month_lag_6                    float16
# item_cnt_month_lag_12                   float16
# date_avg_item_cnt_lag_1                 float16
# date_item_avg_item_cnt_lag_1            float16
# date_item_avg_item_cnt_lag_2            float16
# date_item_avg_item_cnt_lag_3            float16
# date_item_avg_item_cnt_lag_6            float16
# date_item_avg_item_cnt_lag_12           float16
# date_shop_avg_item_cnt_lag_1            float16
# date_shop_avg_item_cnt_lag_2            float16
# date_shop_avg_item_cnt_lag_3            float16
# date_shop_avg_item_cnt_lag_6            float16
# date_shop_avg_item_cnt_lag_12           float16
# date_cat_avg_item_cnt_lag_1             float16
# date_shop_cat_avg_item_cnt_lag_1        float16
# date_shop_type_avg_item_cnt_lag_1       float16
# date_shop_subtype_avg_item_cnt_lag_1    float16
# date_city_avg_item_cnt_lag_1            float16
# date_item_city_avg_item_cnt_lag_1       float16
# date_type_avg_item_cnt_lag_1            float16
# date_subtype_avg_item_cnt_lag_1         float16
# delta_price_lag                         float16
# delta_revenue_lag_1                     float16
# month                                   int8
# days                                    int8
# item_shop_last_sale                     int8
# item_last_sale                          int8
# item_shop_first_sale                    int8
# item_first_sale                         int8
# dtypes: float16(27), float64(1), int16(1), int8(12)
# memory usage: 531.9 MB

# %%
matrix.to_pickle('data.pkl')
del matrix
del cache
del group
del items
del shops
del cats
del train
# leave test for submission
gc.collect();

# %% [markdown]
# # Part 2, XGBOOST and LSTM

# %%
data = pd.read_pickle('data.pkl')

# %%
data.head()

# %% [markdown]
# Select perfect features

# %% [raw]
# data = data[[
#     'date_block_num',
#     'shop_id',
#     'item_id',
#     'item_cnt_month',
#     'city_code',
#     'item_category_id',
#     'type_code',
#     'subtype_code',
#     'item_cnt_month_lag_1',
#     'item_cnt_month_lag_2',
#     'item_cnt_month_lag_3',
#     'item_cnt_month_lag_6',
#     'item_cnt_month_lag_12',
#     'date_avg_item_cnt_lag_1',
#     'date_item_avg_item_cnt_lag_1',
#     'date_item_avg_item_cnt_lag_2',
#     'date_item_avg_item_cnt_lag_3',
#     'date_item_avg_item_cnt_lag_6',
#     'date_item_avg_item_cnt_lag_12',
#     'date_shop_avg_item_cnt_lag_1',
#     'date_shop_avg_item_cnt_lag_2',
#     'date_shop_avg_item_cnt_lag_3',
#     'date_shop_avg_item_cnt_lag_6',
#     'date_shop_avg_item_cnt_lag_12',
#     'date_cat_avg_item_cnt_lag_1',
#     'date_shop_cat_avg_item_cnt_lag_1',
#     #'date_shop_type_avg_item_cnt_lag_1',
#     #'date_shop_subtype_avg_item_cnt_lag_1',
#     'date_city_avg_item_cnt_lag_1',
#     'date_item_city_avg_item_cnt_lag_1',
#     #'date_type_avg_item_cnt_lag_1',
#     #'date_subtype_avg_item_cnt_lag_1',
#     'delta_price_lag',
#     'month',
#     'days',
#     'item_shop_last_sale',
#     'item_last_sale',
#     'item_shop_first_sale',
#     'item_first_sale',
# ]]

# %% [markdown]
# Validation strategy is month 34 for test, 33 months for the train.

# %%
X = data[data.date_block_num <= 33].drop(['item_cnt_month'], axis=1)
Y = data[data.date_block_num <= 33]['item_cnt_month']
#X_valid = data[data.date_block_num == 33].drop(['item_cnt_month'], axis=1)
#Y_valid = data[data.date_block_num == 33]['item_cnt_month']
X_test = data[data.date_block_num == 34].drop(['item_cnt_month'], axis=1)

# %%
del data
gc.collect();

# %% [markdown]
# initialize and fit XGBOOST model

# %%
ts = time.time()

model = XGBRegressor(
    n_jobs=-1,
    learning_rate=0.2,
    max_depth=8,
    n_estimators=1000,
    min_child_weight=300, 
    colsample_bytree=0.8, 
    subsample=0.8, 
    eta=0.3,    
    seed=42)

X_train, X_valid, y_train, y_valid = train_test_split(X, Y, test_size=0.33, random_state=7)
eval_set = [(X_valid, y_valid)]

model.fit(
    X_train, 
    y_train, 
    eval_metric="rmse", 
    eval_set=eval_set,
    verbose=True, 
    early_stopping_rounds = 3)

time.time() - ts
# Out:
# [0]	validation_0-rmse:1.1471
# Will train until validation_0-rmse hasn't improved in 3 rounds.
# [1]	validation_0-rmse:1.07244
# [2]	validation_0-rmse:1.02405
# [3]	validation_0-rmse:0.985356
# [4]	validation_0-rmse:0.961797
# [5]	validation_0-rmse:0.946618
# [6]	validation_0-rmse:0.933737
# [7]	validation_0-rmse:0.924732
# [8]	validation_0-rmse:0.918731
# [9]	validation_0-rmse:0.91397
# [10]	validation_0-rmse:0.910079
# [11]	validation_0-rmse:0.906518
# [12]	validation_0-rmse:0.903835
# [13]	validation_0-rmse:0.901552
# [14]	validation_0-rmse:0.899895
# [15]	validation_0-rmse:0.898814
# [16]	validation_0-rmse:0.897129
# [17]	validation_0-rmse:0.895889
# [18]	validation_0-rmse:0.89462
# [19]	validation_0-rmse:0.893451
# [20]	validation_0-rmse:0.892636
# [21]	validation_0-rmse:0.89169
# [22]	validation_0-rmse:0.89065
# [23]	validation_0-rmse:0.889531
# [24]	validation_0-rmse:0.889167
# [25]	validation_0-rmse:0.888844
# [26]	validation_0-rmse:0.888248
# [27]	validation_0-rmse:0.887695
# [28]	validation_0-rmse:0.886725
# [29]	validation_0-rmse:0.886476
# [30]	validation_0-rmse:0.885221
# [31]	validation_0-rmse:0.884776
# [32]	validation_0-rmse:0.884064
# [33]	validation_0-rmse:0.883648
# [34]	validation_0-rmse:0.882942
# [35]	validation_0-rmse:0.881973
# [36]	validation_0-rmse:0.88174
# [37]	validation_0-rmse:0.881005
# [38]	validation_0-rmse:0.880328
# [39]	validation_0-rmse:0.880004
# [40]	validation_0-rmse:0.879532
# [41]	validation_0-rmse:0.879002
# [42]	validation_0-rmse:0.878799
# [43]	validation_0-rmse:0.878467
# [44]	validation_0-rmse:0.87809
# [45]	validation_0-rmse:0.878001
# [46]	validation_0-rmse:0.877535
# [47]	validation_0-rmse:0.877337
# [48]	validation_0-rmse:0.877166
# [49]	validation_0-rmse:0.876489
# [50]	validation_0-rmse:0.876018
# [51]	validation_0-rmse:0.87581
# [52]	validation_0-rmse:0.87436
# [53]	validation_0-rmse:0.874051
# [54]	validation_0-rmse:0.873878
# [55]	validation_0-rmse:0.873003
# [56]	validation_0-rmse:0.872475
# [57]	validation_0-rmse:0.872063
# [58]	validation_0-rmse:0.871854
# [59]	validation_0-rmse:0.871604
# [60]	validation_0-rmse:0.871383
# [61]	validation_0-rmse:0.871053
# [62]	validation_0-rmse:0.870742
# [63]	validation_0-rmse:0.870628
# [64]	validation_0-rmse:0.87032
# [65]	validation_0-rmse:0.870259
# [66]	validation_0-rmse:0.869691
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-10-e0605b6e6564> in <module>
#      21     eval_set=eval_set,
#      22     verbose=True,
# ---> 23     early_stopping_rounds = 3)
#      24
#      25 time.time() - ts
#
# /usr/local/lib/python3.7/site-packages/xgboost/sklearn.py in fit(self, X, y, sample_weight, eval_set, eval_metric, early_stopping_rounds, verbose, xgb_model, sample_weight_eval_set, callbacks)
#     376                               evals_result=evals_result, obj=obj, feval=feval,
#     377                               verbose_eval=verbose, xgb_model=xgb_model,
# --> 378                               callbacks=callbacks)
#     379
#     380         if evals_result:
#
# /usr/local/lib/python3.7/site-packages/xgboost/training.py in train(params, dtrain, num_boost_round, evals, obj, feval, maximize, early_stopping_rounds, evals_result, verbose_eval, xgb_model, callbacks, learning_rates)
#     214                            evals=evals,
#     215                            obj=obj, feval=feval,
# --> 216                            xgb_model=xgb_model, callbacks=callbacks)
#     217
#     218
#
# /usr/local/lib/python3.7/site-packages/xgboost/training.py in _train_internal(params, dtrain, num_boost_round, evals, obj, feval, xgb_model, callbacks)
#      72         # Skip the first update if it is a recovery step.
#      73         if version % 2 == 0:
# ---> 74             bst.update(dtrain, i, obj)
#      75             bst.save_rabit_checkpoint()
#      76             version += 1
#
# /usr/local/lib/python3.7/site-packages/xgboost/core.py in update(self, dtrain, iteration, fobj)
#    1108         if fobj is None:
#    1109             _check_call(_LIB.XGBoosterUpdateOneIter(self.handle, ctypes.c_int(iteration),
# -> 1110                                                     dtrain.handle))
#    1111         else:
#    1112             pred = self.predict(dtrain)
#
# KeyboardInterrupt:

# %%
# save the model to disk
filename = 'XGboostModel.sav'
pickle.dump(model, open(filename, 'wb'))
 
# some time later...

# %%
# load the model from disk
#loaded_model = pickle.load(open(filename, 'rb'))

# %% [markdown]
# predict xgboot

# %%
#Y_test = loaded_model.predict(X_test).clip(0, 20)
Y_test = model.predict(X_test).clip(0, 20)



submission = pd.DataFrame({
    "ID": test.index, 
    "item_cnt_month": Y_test
})

# %% [markdown]
# #### Initalize RNN LSTM

# %%
ts = time.time()
print('-Initialize RNN with LSTM')

model = Sequential()
model.add(LSTM(units=64, input_shape=(1, 34)))
model.add(Dropout(0.3))
model.add(Dense(1))

model.compile(loss='mse',
              optimizer='adam',
              metrics=['mean_squared_error'])
model.summary()
# Out:
# -Initialize RNN with LSTM
# WARNING:tensorflow:From /usr/local/lib/python3.7/site-packages/tensorflow/python/framework/op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# WARNING:tensorflow:From /usr/local/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:3445: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_1 (LSTM)                (None, 64)                25344
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 64)                0
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 65
# =================================================================
# Total params: 25,409
# Trainable params: 25,409
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# #### Model fit RNN LSTM

# %%
ts = time.time()

print('-Reshape x_train, x_test')
X_train = X.values
X_train = np.reshape(X_train, (X_train.shape[0], 1, X_train.shape[1]))
X_test = np.reshape(X_test.values, (X_test.shape[0], 1, X_test.shape[1]))

X_valid = np.reshape(X_valid.values, (X_valid.shape[0], 1, X_valid.shape[1]))
eval_set = (X_valid, y_valid)

print('-Model fit')

history = model.fit(X_train, Y, batch_size=2048, epochs=200, validation_data=eval_set)

time.time() - ts
# Out:
# -Reshape x_train, x_test
# -Model fit
# WARNING:tensorflow:From /usr/local/lib/python3.7/site-packages/tensorflow/python/ops/math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# Train on 6425094 samples, validate on 2120282 samples
# Epoch 1/200
# 6425094/6425094 [==============================] - 44s 7us/step - loss: 1.2213 - mean_squared_error: 1.2213 - val_loss: 1.0380 - val_mean_squared_error: 1.0380
# Epoch 2/200
# 6425094/6425094 [==============================] - 44s 7us/step - loss: 1.1045 - mean_squared_error: 1.1045 - val_loss: 1.0356 - val_mean_squared_error: 1.0356
# Epoch 3/200
# 6425094/6425094 [==============================] - 44s 7us/step - loss: 1.0584 - mean_squared_error: 1.0584 - val_loss: 0.9848 - val_mean_squared_error: 0.9848
# Epoch 4/200
# 6425094/6425094 [==============================] - 39s 6us/step - loss: 1.0479 - mean_squared_error: 1.0479 - val_loss: 0.9443 - val_mean_squared_error: 0.9443
# Epoch 5/200
# 6425094/6425094 [==============================] - 39s 6us/step - loss: 1.0609 - mean_squared_error: 1.0609 - val_loss: 0.9750 - val_mean_squared_error: 0.9750
# Epoch 6/200
# 6425094/6425094 [==============================] - 39s 6us/step - loss: 1.0503 - mean_squared_error: 1.0503 - val_loss: 0.9180 - val_mean_squared_error: 0.9180
# Epoch 7/200
# 6425094/6425094 [==============================] - 39s 6us/step - loss: 1.0107 - mean_squared_error: 1.0107 - val_loss: 0.9210 - val_mean_squared_error: 0.9210
# Epoch 8/200
# 6425094/6425094 [==============================] - 39s 6us/step - loss: 0.9972 - mean_squared_error: 0.9972 - val_loss: 0.9270 - val_mean_squared_error: 0.9270
# Epoch 9/200
# 6425094/6425094 [==============================] - 39s 6us/step - loss: 0.9969 - mean_squared_error: 0.9969 - val_loss: 1.2791 - val_mean_squared_error: 1.2791
# Epoch 10/200
# 6425094/6425094 [==============================] - 39s 6us/step - loss: 1.0055 - mean_squared_error: 1.0055 - val_loss: 0.8992 - val_mean_squared_error: 0.8992
# Epoch 11/200
# 6425094/6425094 [==============================] - 39s 6us/step - loss: 0.9901 - mean_squared_error: 0.9901 - val_loss: 0.9364 - val_mean_squared_error: 0.9364
# Epoch 12/200
# 6425094/6425094 [==============================] - 39s 6us/step - loss: 0.9906 - mean_squared_error: 0.9906 - val_loss: 0.9034 - val_mean_squared_error: 0.9034
# Epoch 13/200
# 6425094/6425094 [==============================] - 39s 6us/step - loss: 0.9929 - mean_squared_error: 0.9929 - val_loss: 0.8813 - val_mean_squared_error: 0.8813
# Epoch 14/200
# 6425094/6425094 [==============================] - 39s 6us/step - loss: 0.9929 - mean_squared_error: 0.9929 - val_loss: 0.9092 - val_mean_squared_error: 0.9092
# Epoch 15/200
# 6425094/6425094 [==============================] - 39s 6us/step - loss: 0.9829 - mean_squared_error: 0.9829 - val_loss: 0.8931 - val_mean_squared_error: 0.8931
# Epoch 16/200
# 6425094/6425094 [==============================] - 39s 6us/step - loss: 0.9776 - mean_squared_error: 0.9776 - val_loss: 0.8904 - val_mean_squared_error: 0.8904
# Epoch 17/200
# 6425094/6425094 [==============================] - 39s 6us/step - loss: 0.9633 - mean_squared_error: 0.9633 - val_loss: 0.8968 - val_mean_squared_error: 0.8968
# Epoch 18/200
# 6425094/6425094 [==============================] - 39s 6us/step - loss: 0.9709 - mean_squared_error: 0.9709 - val_loss: 0.9156 - val_mean_squared_error: 0.9156
# Epoch 19/200
# 6425094/6425094 [==============================] - 39s 6us/step - loss: 0.9754 - mean_squared_error: 0.9754 - val_loss: 0.9804 - val_mean_squared_error: 0.9804
# Epoch 20/200
# 6425094/6425094 [==============================] - 39s 6us/step - loss: 0.9727 - mean_squared_error: 0.9727 - val_loss: 0.8926 - val_mean_squared_error: 0.8926
# Epoch 21/200
# 6425094/6425094 [==============================] - 39s 6us/step - loss: 0.9689 - mean_squared_error: 0.9689 - val_loss: 0.8917 - val_mean_squared_error: 0.8917
# Epoch 22/200
# 6425094/6425094 [==============================] - 39s 6us/step - loss: 0.9700 - mean_squared_error: 0.9700 - val_loss: 0.8676 - val_mean_squared_error: 0.8676
# Epoch 23/200
# 6425094/6425094 [==============================] - 39s 6us/step - loss: 0.9695 - mean_squared_error: 0.9695 - val_loss: 0.8983 - val_mean_squared_error: 0.8983
# Epoch 24/200
# 6425094/6425094 [==============================] - 40s 6us/step - loss: 0.9566 - mean_squared_error: 0.9566 - val_loss: 0.8721 - val_mean_squared_error: 0.8721
# Epoch 25/200
# 6425094/6425094 [==============================] - 39s 6us/step - loss: 0.9624 - mean_squared_error: 0.9624 - val_loss: 0.8717 - val_mean_squared_error: 0.8717
# Epoch 26/200
# 6425094/6425094 [==============================] - 39s 6us/step - loss: 0.9650 - mean_squared_error: 0.9650 - val_loss: 0.9123 - val_mean_squared_error: 0.9123
# Epoch 27/200
# 6425094/6425094 [==============================] - 39s 6us/step - loss: 0.9655 - mean_squared_error: 0.9655 - val_loss: 0.9015 - val_mean_squared_error: 0.9015
# Epoch 28/200
# 6425094/6425094 [==============================] - 39s 6us/step - loss: 0.9675 - mean_squared_error: 0.9675 - val_loss: 0.8639 - val_mean_squared_error: 0.8639
# Epoch 29/200
# 6425094/6425094 [==============================] - 39s 6us/step - loss: 0.9693 - mean_squared_error: 0.9693 - val_loss: 0.8628 - val_mean_squared_error: 0.8628
# Epoch 30/200
# 6425094/6425094 [==============================] - 39s 6us/step - loss: 0.9660 - mean_squared_error: 0.9660 - val_loss: 0.8806 - val_mean_squared_error: 0.8806
# Epoch 31/200
# 6425094/6425094 [==============================] - 39s 6us/step - loss: 0.9583 - mean_squared_error: 0.9583 - val_loss: 0.8691 - val_mean_squared_error: 0.8691
# Epoch 32/200
# 6425094/6425094 [==============================] - 40s 6us/step - loss: 0.9605 - mean_squared_error: 0.9605 - val_loss: 0.8641 - val_mean_squared_error: 0.8641
# Epoch 33/200
# 6425094/6425094 [==============================] - 39s 6us/step - loss: 0.9614 - mean_squared_error: 0.9614 - val_loss: 0.8581 - val_mean_squared_error: 0.8581
# Epoch 34/200
# 6425094/6425094 [==============================] - 40s 6us/step - loss: 0.9599 - mean_squared_error: 0.9599 - val_loss: 0.8674 - val_mean_squared_error: 0.8674
# Epoch 35/200
# 6425094/6425094 [==============================] - 39s 6us/step - loss: 0.9566 - mean_squared_error: 0.9566 - val_loss: 0.8620 - val_mean_squared_error: 0.8620
# Epoch 36/200
# 6425094/6425094 [==============================] - 39s 6us/step - loss: 0.9519 - mean_squared_error: 0.9519 - val_loss: 0.8474 - val_mean_squared_error: 0.8474
# Epoch 37/200
# 6425094/6425094 [==============================] - 39s 6us/step - loss: 0.9620 - mean_squared_error: 0.9620 - val_loss: 0.9070 - val_mean_squared_error: 0.9070
# Epoch 38/200
# 6425094/6425094 [==============================] - 39s 6us/step - loss: 0.9534 - mean_squared_error: 0.9534 - val_loss: 0.8725 - val_mean_squared_error: 0.8725
# Epoch 39/200
# 6425094/6425094 [==============================] - 39s 6us/step - loss: 0.9631 - mean_squared_error: 0.9631 - val_loss: 0.8888 - val_mean_squared_error: 0.8888
# Epoch 40/200
# 6425094/6425094 [==============================] - 40s 6us/step - loss: 0.9634 - mean_squared_error: 0.9634 - val_loss: 0.8946 - val_mean_squared_error: 0.8946
# Epoch 41/200
# 6425094/6425094 [==============================] - 39s 6us/step - loss: 0.9604 - mean_squared_error: 0.9604 - val_loss: 0.8816 - val_mean_squared_error: 0.8816
# Epoch 42/200
# 6425094/6425094 [==============================] - 39s 6us/step - loss: 0.9575 - mean_squared_error: 0.9575 - val_loss: 0.8705 - val_mean_squared_error: 0.8705
# Epoch 43/200
# 6425094/6425094 [==============================] - 39s 6us/step - loss: 0.9604 - mean_squared_error: 0.9604 - val_loss: 0.8499 - val_mean_squared_error: 0.8499
# Epoch 44/200
# 6425094/6425094 [==============================] - 39s 6us/step - loss: 0.9538 - mean_squared_error: 0.9538 - val_loss: 0.8692 - val_mean_squared_error: 0.8692
# Epoch 45/200
# 6425094/6425094 [==============================] - 39s 6us/step - loss: 0.9542 - mean_squared_error: 0.9542 - val_loss: 0.9008 - val_mean_squared_error: 0.9008
# Epoch 46/200
# 6425094/6425094 [==============================] - 39s 6us/step - loss: 0.9638 - mean_squared_error: 0.9638 - val_loss: 0.9502 - val_mean_squared_error: 0.9502
# Epoch 47/200
# 6425094/6425094 [==============================] - 39s 6us/step - loss: 0.9581 - mean_squared_error: 0.9581 - val_loss: 0.8679 - val_mean_squared_error: 0.8679
# Epoch 48/200
# 6425094/6425094 [==============================] - 39s 6us/step - loss: 0.9552 - mean_squared_error: 0.9552 - val_loss: 0.8788 - val_mean_squared_error: 0.8788
# Epoch 49/200
# 6425094/6425094 [==============================] - 40s 6us/step - loss: 0.9525 - mean_squared_error: 0.9525 - val_loss: 0.8777 - val_mean_squared_error: 0.8777
# Epoch 50/200
# 6425094/6425094 [==============================] - 39s 6us/step - loss: 0.9499 - mean_squared_error: 0.9499 - val_loss: 0.8543 - val_mean_squared_error: 0.8543
# Epoch 51/200
# 6425094/6425094 [==============================] - 39s 6us/step - loss: 0.9526 - mean_squared_error: 0.9526 - val_loss: 0.8674 - val_mean_squared_error: 0.8674
# Epoch 52/200
# 6425094/6425094 [==============================] - 39s 6us/step - loss: 0.9587 - mean_squared_error: 0.9587 - val_loss: 0.8796 - val_mean_squared_error: 0.8796
# Epoch 53/200
# 6425094/6425094 [==============================] - 39s 6us/step - loss: 0.9525 - mean_squared_error: 0.9525 - val_loss: 0.8763 - val_mean_squared_error: 0.8763
# Epoch 54/200
# 6425094/6425094 [==============================] - 39s 6us/step - loss: 0.9531 - mean_squared_error: 0.9531 - val_loss: 0.8658 - val_mean_squared_error: 0.8658
# Epoch 55/200
# 6425094/6425094 [==============================] - 39s 6us/step - loss: 0.9578 - mean_squared_error: 0.9578 - val_loss: 0.8616 - val_mean_squared_error: 0.8616
# Epoch 56/200
# 6425094/6425094 [==============================] - 39s 6us/step - loss: 0.9571 - mean_squared_error: 0.9571 - val_loss: 0.8805 - val_mean_squared_error: 0.8805
# Epoch 57/200
# 6425094/6425094 [==============================] - 40s 6us/step - loss: 0.9538 - mean_squared_error: 0.9538 - val_loss: 0.8767 - val_mean_squared_error: 0.8767
# Epoch 58/200
# 6425094/6425094 [==============================] - 39s 6us/step - loss: 0.9542 - mean_squared_error: 0.9542 - val_loss: 0.8576 - val_mean_squared_error: 0.8576
# Epoch 59/200
# 6425094/6425094 [==============================] - 39s 6us/step - loss: 0.9499 - mean_squared_error: 0.9499 - val_loss: 0.8855 - val_mean_squared_error: 0.8855
# Epoch 60/200
# 6425094/6425094 [==============================] - 39s 6us/step - loss: 0.9497 - mean_squared_error: 0.9497 - val_loss: 0.8707 - val_mean_squared_error: 0.8707
# Epoch 61/200
# 6425094/6425094 [==============================] - 39s 6us/step - loss: 0.9492 - mean_squared_error: 0.9492 - val_loss: 0.8991 - val_mean_squared_error: 0.8991
# Epoch 62/200
# 6425094/6425094 [==============================] - 39s 6us/step - loss: 0.9490 - mean_squared_error: 0.9490 - val_loss: 0.8610 - val_mean_squared_error: 0.8610
# Epoch 63/200
# 6425094/6425094 [==============================] - 39s 6us/step - loss: 0.9534 - mean_squared_error: 0.9534 - val_loss: 0.8808 - val_mean_squared_error: 0.8808
# Epoch 64/200
# 6425094/6425094 [==============================] - 39s 6us/step - loss: 0.9524 - mean_squared_error: 0.9524 - val_loss: 0.8812 - val_mean_squared_error: 0.8812
# Epoch 65/200
# 6425094/6425094 [==============================] - 40s 6us/step - loss: 0.9493 - mean_squared_error: 0.9493 - val_loss: 0.8443 - val_mean_squared_error: 0.8443
# Epoch 66/200
# 6425094/6425094 [==============================] - 39s 6us/step - loss: 0.9525 - mean_squared_error: 0.9525 - val_loss: 0.8843 - val_mean_squared_error: 0.8843
# Epoch 67/200
# 6425094/6425094 [==============================] - 39s 6us/step - loss: 0.9553 - mean_squared_error: 0.9553 - val_loss: 0.8742 - val_mean_squared_error: 0.8742
# Epoch 68/200
# 6425094/6425094 [==============================] - 39s 6us/step - loss: 0.9458 - mean_squared_error: 0.9458 - val_loss: 0.8867 - val_mean_squared_error: 0.8867
# Epoch 69/200
# 6425094/6425094 [==============================] - 39s 6us/step - loss: 0.9466 - mean_squared_error: 0.9466 - val_loss: 0.8679 - val_mean_squared_error: 0.8679
# Epoch 70/200
# 6425094/6425094 [==============================] - 39s 6us/step - loss: 0.9452 - mean_squared_error: 0.9452 - val_loss: 0.8675 - val_mean_squared_error: 0.8675
# Epoch 71/200
# 6425094/6425094 [==============================] - 43s 7us/step - loss: 0.9492 - mean_squared_error: 0.9492 - val_loss: 0.8485 - val_mean_squared_error: 0.8485
# Epoch 72/200
# 6425094/6425094 [==============================] - 40s 6us/step - loss: 0.9508 - mean_squared_error: 0.9508 - val_loss: 0.8744 - val_mean_squared_error: 0.8744
# Epoch 73/200
# 6425094/6425094 [==============================] - 42s 7us/step - loss: 0.9496 - mean_squared_error: 0.9496 - val_loss: 0.8585 - val_mean_squared_error: 0.8585
# Epoch 74/200
# 6425094/6425094 [==============================] - 45s 7us/step - loss: 0.9480 - mean_squared_error: 0.9480 - val_loss: 0.8559 - val_mean_squared_error: 0.8559
# Epoch 75/200
# 6425094/6425094 [==============================] - 41s 6us/step - loss: 0.9488 - mean_squared_error: 0.9488 - val_loss: 0.8553 - val_mean_squared_error: 0.8553
# Epoch 76/200
# 6425094/6425094 [==============================] - 40s 6us/step - loss: 0.9485 - mean_squared_error: 0.9485 - val_loss: 0.8603 - val_mean_squared_error: 0.8603
# Epoch 77/200
# 6425094/6425094 [==============================] - 40s 6us/step - loss: 0.9475 - mean_squared_error: 0.9475 - val_loss: 0.8725 - val_mean_squared_error: 0.8725
# Epoch 78/200
# 6425094/6425094 [==============================] - 40s 6us/step - loss: 0.9466 - mean_squared_error: 0.9466 - val_loss: 0.8887 - val_mean_squared_error: 0.8887
# Epoch 79/200
# 6425094/6425094 [==============================] - 40s 6us/step - loss: 0.9490 - mean_squared_error: 0.9490 - val_loss: 0.8698 - val_mean_squared_error: 0.8698
# Epoch 80/200
# 6425094/6425094 [==============================] - 42s 7us/step - loss: 0.9510 - mean_squared_error: 0.9510 - val_loss: 0.8866 - val_mean_squared_error: 0.8866
# Epoch 81/200
# 6425094/6425094 [==============================] - 39s 6us/step - loss: 0.9477 - mean_squared_error: 0.9477 - val_loss: 0.8721 - val_mean_squared_error: 0.8721
# Epoch 82/200
# 6425094/6425094 [==============================] - 39s 6us/step - loss: 0.9500 - mean_squared_error: 0.9500 - val_loss: 0.8615 - val_mean_squared_error: 0.8615
# Epoch 83/200
# 6425094/6425094 [==============================] - 39s 6us/step - loss: 0.9530 - mean_squared_error: 0.9530 - val_loss: 0.8612 - val_mean_squared_error: 0.8612
# Epoch 84/200
# 6425094/6425094 [==============================] - 39s 6us/step - loss: 0.9478 - mean_squared_error: 0.9478 - val_loss: 0.8759 - val_mean_squared_error: 0.8759
# Epoch 85/200
# 6425094/6425094 [==============================] - 39s 6us/step - loss: 0.9483 - mean_squared_error: 0.9483 - val_loss: 0.8450 - val_mean_squared_error: 0.8450
# Epoch 86/200
# 6425094/6425094 [==============================] - 39s 6us/step - loss: 0.9530 - mean_squared_error: 0.9530 - val_loss: 0.8749 - val_mean_squared_error: 0.8749
# Epoch 87/200
# 6425094/6425094 [==============================] - 40s 6us/step - loss: 0.9480 - mean_squared_error: 0.9480 - val_loss: 0.8745 - val_mean_squared_error: 0.8745
# Epoch 88/200
# 6425094/6425094 [==============================] - 39s 6us/step - loss: 0.9505 - mean_squared_error: 0.9505 - val_loss: 0.8793 - val_mean_squared_error: 0.8793
# Epoch 89/200
# 6425094/6425094 [==============================] - 39s 6us/step - loss: 0.9480 - mean_squared_error: 0.9480 - val_loss: 0.8465 - val_mean_squared_error: 0.8465
# Epoch 90/200
# 6425094/6425094 [==============================] - 39s 6us/step - loss: 0.9527 - mean_squared_error: 0.9527 - val_loss: 0.8590 - val_mean_squared_error: 0.8590
# Epoch 91/200
# 6425094/6425094 [==============================] - 39s 6us/step - loss: 0.9487 - mean_squared_error: 0.9487 - val_loss: 0.8879 - val_mean_squared_error: 0.8879
# Epoch 92/200
# 6425094/6425094 [==============================] - 39s 6us/step - loss: 0.9568 - mean_squared_error: 0.9568 - val_loss: 0.8777 - val_mean_squared_error: 0.8777
# Epoch 93/200
# 6425094/6425094 [==============================] - 39s 6us/step - loss: 0.9454 - mean_squared_error: 0.9454 - val_loss: 0.8614 - val_mean_squared_error: 0.8614
# Epoch 94/200
# 6425094/6425094 [==============================] - 40s 6us/step - loss: 0.9458 - mean_squared_error: 0.9458 - val_loss: 0.8574 - val_mean_squared_error: 0.8574
# Epoch 95/200
# 6425094/6425094 [==============================] - 40s 6us/step - loss: 0.9523 - mean_squared_error: 0.9523 - val_loss: 0.8663 - val_mean_squared_error: 0.8663
# Epoch 96/200
# 6425094/6425094 [==============================] - 39s 6us/step - loss: 0.9508 - mean_squared_error: 0.9508 - val_loss: 0.8665 - val_mean_squared_error: 0.8665
# Epoch 97/200
# 6425094/6425094 [==============================] - 40s 6us/step - loss: 0.9465 - mean_squared_error: 0.9465 - val_loss: 0.8547 - val_mean_squared_error: 0.8547
# Epoch 98/200
# 6425094/6425094 [==============================] - 39s 6us/step - loss: 0.9515 - mean_squared_error: 0.9515 - val_loss: 0.8781 - val_mean_squared_error: 0.8781
# Epoch 99/200
# 6425094/6425094 [==============================] - 39s 6us/step - loss: 0.9470 - mean_squared_error: 0.9470 - val_loss: 0.8767 - val_mean_squared_error: 0.8767
# Epoch 100/200
# 6425094/6425094 [==============================] - 39s 6us/step - loss: 0.9485 - mean_squared_error: 0.9485 - val_loss: 0.8909 - val_mean_squared_error: 0.8909
# Epoch 101/200
# 6425094/6425094 [==============================] - 39s 6us/step - loss: 0.9461 - mean_squared_error: 0.9461 - val_loss: 0.8431 - val_mean_squared_error: 0.8431
# Epoch 102/200
# 6425094/6425094 [==============================] - 40s 6us/step - loss: 0.9421 - mean_squared_error: 0.9421 - val_loss: 0.8545 - val_mean_squared_error: 0.8545
# Epoch 103/200
# 6425094/6425094 [==============================] - 39s 6us/step - loss: 0.9440 - mean_squared_error: 0.9440 - val_loss: 0.8673 - val_mean_squared_error: 0.8673
# Epoch 104/200
# 6425094/6425094 [==============================] - 39s 6us/step - loss: 0.9496 - mean_squared_error: 0.9496 - val_loss: 0.8708 - val_mean_squared_error: 0.8708
# Epoch 105/200
# 6425094/6425094 [==============================] - 39s 6us/step - loss: 0.9452 - mean_squared_error: 0.9452 - val_loss: 0.8799 - val_mean_squared_error: 0.8799
# Epoch 106/200
# 6425094/6425094 [==============================] - 39s 6us/step - loss: 0.9456 - mean_squared_error: 0.9456 - val_loss: 0.8629 - val_mean_squared_error: 0.8629
# Epoch 107/200
# 6425094/6425094 [==============================] - 39s 6us/step - loss: 0.9457 - mean_squared_error: 0.9457 - val_loss: 0.8555 - val_mean_squared_error: 0.8555
# Epoch 108/200
# 6425094/6425094 [==============================] - 40s 6us/step - loss: 0.9461 - mean_squared_error: 0.9461 - val_loss: 0.8493 - val_mean_squared_error: 0.8493
# Epoch 109/200
# 6425094/6425094 [==============================] - 39s 6us/step - loss: 0.9445 - mean_squared_error: 0.9445 - val_loss: 0.8674 - val_mean_squared_error: 0.8674
# Epoch 110/200
# 6425094/6425094 [==============================] - 42s 7us/step - loss: 0.9419 - mean_squared_error: 0.9419 - val_loss: 0.8659 - val_mean_squared_error: 0.8659
# Epoch 111/200
# 6425094/6425094 [==============================] - 39s 6us/step - loss: 0.9442 - mean_squared_error: 0.9442 - val_loss: 0.8567 - val_mean_squared_error: 0.8567
# Epoch 112/200
# 6425094/6425094 [==============================] - 39s 6us/step - loss: 0.9461 - mean_squared_error: 0.9461 - val_loss: 0.8497 - val_mean_squared_error: 0.8497
# Epoch 113/200
# 6425094/6425094 [==============================] - 40s 6us/step - loss: 0.9426 - mean_squared_error: 0.9426 - val_loss: 0.8683 - val_mean_squared_error: 0.8683
# Epoch 114/200
# 6425094/6425094 [==============================] - 39s 6us/step - loss: 0.9433 - mean_squared_error: 0.9433 - val_loss: 0.8719 - val_mean_squared_error: 0.8719
# Epoch 115/200
# 6425094/6425094 [==============================] - 39s 6us/step - loss: 0.9423 - mean_squared_error: 0.9423 - val_loss: 0.8612 - val_mean_squared_error: 0.8612
# Epoch 116/200
# 6425094/6425094 [==============================] - 39s 6us/step - loss: 0.9461 - mean_squared_error: 0.9461 - val_loss: 0.8528 - val_mean_squared_error: 0.8528
# Epoch 117/200
# 6425094/6425094 [==============================] - 39s 6us/step - loss: 0.9480 - mean_squared_error: 0.9480 - val_loss: 0.8798 - val_mean_squared_error: 0.8798
# Epoch 118/200
# 6425094/6425094 [==============================] - 39s 6us/step - loss: 0.9446 - mean_squared_error: 0.9446 - val_loss: 0.8521 - val_mean_squared_error: 0.8521
# Epoch 119/200
# 6425094/6425094 [==============================] - 39s 6us/step - loss: 0.9542 - mean_squared_error: 0.9542 - val_loss: 0.8554 - val_mean_squared_error: 0.8554
# Epoch 120/200
# 6425094/6425094 [==============================] - 39s 6us/step - loss: 0.9460 - mean_squared_error: 0.9460 - val_loss: 0.8756 - val_mean_squared_error: 0.8756
# Epoch 121/200
# 6425094/6425094 [==============================] - 39s 6us/step - loss: 0.9522 - mean_squared_error: 0.9522 - val_loss: 0.8463 - val_mean_squared_error: 0.8463
# Epoch 122/200
# 6425094/6425094 [==============================] - 39s 6us/step - loss: 0.9425 - mean_squared_error: 0.9425 - val_loss: 0.8508 - val_mean_squared_error: 0.8508
# Epoch 123/200
# 6425094/6425094 [==============================] - 39s 6us/step - loss: 0.9423 - mean_squared_error: 0.9423 - val_loss: 0.8578 - val_mean_squared_error: 0.8578
# Epoch 124/200
# 6425094/6425094 [==============================] - 39s 6us/step - loss: 0.9501 - mean_squared_error: 0.9501 - val_loss: 0.8687 - val_mean_squared_error: 0.8687
# Epoch 125/200
# 6425094/6425094 [==============================] - 41s 6us/step - loss: 0.9488 - mean_squared_error: 0.9488 - val_loss: 0.8515 - val_mean_squared_error: 0.8515
# Epoch 126/200
# 6425094/6425094 [==============================] - 39s 6us/step - loss: 0.9480 - mean_squared_error: 0.9480 - val_loss: 0.8733 - val_mean_squared_error: 0.8733
# Epoch 127/200
# 6425094/6425094 [==============================] - 39s 6us/step - loss: 0.9460 - mean_squared_error: 0.9460 - val_loss: 0.8622 - val_mean_squared_error: 0.8622
# Epoch 128/200
# 6425094/6425094 [==============================] - 39s 6us/step - loss: 0.9427 - mean_squared_error: 0.9427 - val_loss: 0.8641 - val_mean_squared_error: 0.8641
# Epoch 129/200
# 6425094/6425094 [==============================] - 39s 6us/step - loss: 0.9478 - mean_squared_error: 0.9478 - val_loss: 0.8930 - val_mean_squared_error: 0.8930
# Epoch 130/200
# 6425094/6425094 [==============================] - 39s 6us/step - loss: 0.9437 - mean_squared_error: 0.9437 - val_loss: 0.8657 - val_mean_squared_error: 0.8657
# Epoch 131/200
# 6425094/6425094 [==============================] - 39s 6us/step - loss: 0.9447 - mean_squared_error: 0.9447 - val_loss: 0.8670 - val_mean_squared_error: 0.8670
# Epoch 132/200
# 6425094/6425094 [==============================] - 39s 6us/step - loss: 0.9420 - mean_squared_error: 0.9420 - val_loss: 0.8526 - val_mean_squared_error: 0.8526
# Epoch 133/200
# 6425094/6425094 [==============================] - 39s 6us/step - loss: 0.9437 - mean_squared_error: 0.9437 - val_loss: 0.8680 - val_mean_squared_error: 0.8680
# Epoch 134/200
# 6425094/6425094 [==============================] - 39s 6us/step - loss: 0.9463 - mean_squared_error: 0.9463 - val_loss: 0.8787 - val_mean_squared_error: 0.8787
# Epoch 135/200
# 6425094/6425094 [==============================] - 39s 6us/step - loss: 0.9528 - mean_squared_error: 0.9528 - val_loss: 0.8834 - val_mean_squared_error: 0.8834
# Epoch 136/200
# 6425094/6425094 [==============================] - 39s 6us/step - loss: 0.9424 - mean_squared_error: 0.9424 - val_loss: 0.8546 - val_mean_squared_error: 0.8546
# Epoch 137/200
# 6425094/6425094 [==============================] - 39s 6us/step - loss: 0.9400 - mean_squared_error: 0.9400 - val_loss: 0.8572 - val_mean_squared_error: 0.8572
# Epoch 138/200
# 6425094/6425094 [==============================] - 39s 6us/step - loss: 0.9478 - mean_squared_error: 0.9478 - val_loss: 0.8724 - val_mean_squared_error: 0.8724
# Epoch 139/200
# 6425094/6425094 [==============================] - 39s 6us/step - loss: 0.9449 - mean_squared_error: 0.9449 - val_loss: 0.8454 - val_mean_squared_error: 0.8454
# Epoch 140/200
# 6425094/6425094 [==============================] - 41s 6us/step - loss: 0.9462 - mean_squared_error: 0.9462 - val_loss: 0.8653 - val_mean_squared_error: 0.8653
# Epoch 141/200
# 6425094/6425094 [==============================] - 40s 6us/step - loss: 0.9449 - mean_squared_error: 0.9449 - val_loss: 0.8781 - val_mean_squared_error: 0.8781
# Epoch 142/200
# 6425094/6425094 [==============================] - 39s 6us/step - loss: 0.9432 - mean_squared_error: 0.9432 - val_loss: 0.8815 - val_mean_squared_error: 0.8815
# Epoch 143/200
# 6425094/6425094 [==============================] - 39s 6us/step - loss: 0.9473 - mean_squared_error: 0.9473 - val_loss: 0.8585 - val_mean_squared_error: 0.8585
# Epoch 144/200
# 6425094/6425094 [==============================] - 39s 6us/step - loss: 0.9439 - mean_squared_error: 0.9439 - val_loss: 0.8493 - val_mean_squared_error: 0.8493
# Epoch 145/200
# 6425094/6425094 [==============================] - 40s 6us/step - loss: 0.9462 - mean_squared_error: 0.9462 - val_loss: 0.8549 - val_mean_squared_error: 0.8549
# Epoch 146/200
# 6425094/6425094 [==============================] - 39s 6us/step - loss: 0.9430 - mean_squared_error: 0.9430 - val_loss: 0.8645 - val_mean_squared_error: 0.8645
# Epoch 147/200
# 6425094/6425094 [==============================] - 39s 6us/step - loss: 0.9421 - mean_squared_error: 0.9421 - val_loss: 0.8559 - val_mean_squared_error: 0.8559
# Epoch 148/200
# 6425094/6425094 [==============================] - 39s 6us/step - loss: 0.9504 - mean_squared_error: 0.9504 - val_loss: 0.8673 - val_mean_squared_error: 0.8673
# Epoch 149/200
# 6425094/6425094 [==============================] - 39s 6us/step - loss: 0.9469 - mean_squared_error: 0.9469 - val_loss: 0.8753 - val_mean_squared_error: 0.8753
# Epoch 150/200
# 6425094/6425094 [==============================] - 39s 6us/step - loss: 0.9540 - mean_squared_error: 0.9540 - val_loss: 0.8429 - val_mean_squared_error: 0.8429
# Epoch 151/200
# 6425094/6425094 [==============================] - 39s 6us/step - loss: 0.9430 - mean_squared_error: 0.9430 - val_loss: 0.8639 - val_mean_squared_error: 0.8639
# Epoch 152/200
# 6425094/6425094 [==============================] - 39s 6us/step - loss: 0.9559 - mean_squared_error: 0.9559 - val_loss: 0.8966 - val_mean_squared_error: 0.8966
# Epoch 153/200
# 6425094/6425094 [==============================] - 39s 6us/step - loss: 0.9504 - mean_squared_error: 0.9504 - val_loss: 0.8578 - val_mean_squared_error: 0.8578
# Epoch 154/200
# 6425094/6425094 [==============================] - 40s 6us/step - loss: 0.9419 - mean_squared_error: 0.9419 - val_loss: 0.8643 - val_mean_squared_error: 0.8643
# Epoch 155/200
# 6425094/6425094 [==============================] - 40s 6us/step - loss: 0.9446 - mean_squared_error: 0.9446 - val_loss: 0.8611 - val_mean_squared_error: 0.8611
# Epoch 156/200
# 6425094/6425094 [==============================] - 40s 6us/step - loss: 0.9434 - mean_squared_error: 0.9434 - val_loss: 0.8873 - val_mean_squared_error: 0.8873
# Epoch 157/200
# 6425094/6425094 [==============================] - 39s 6us/step - loss: 0.9477 - mean_squared_error: 0.9477 - val_loss: 0.8496 - val_mean_squared_error: 0.8496
# Epoch 158/200
# 6425094/6425094 [==============================] - 39s 6us/step - loss: 0.9405 - mean_squared_error: 0.9405 - val_loss: 0.8563 - val_mean_squared_error: 0.8563
# Epoch 159/200
# 6425094/6425094 [==============================] - 39s 6us/step - loss: 0.9475 - mean_squared_error: 0.9475 - val_loss: 0.8974 - val_mean_squared_error: 0.8974
# Epoch 160/200
# 6425094/6425094 [==============================] - 39s 6us/step - loss: 0.9521 - mean_squared_error: 0.9521 - val_loss: 0.8528 - val_mean_squared_error: 0.8528
# Epoch 161/200
# 6425094/6425094 [==============================] - 39s 6us/step - loss: 0.9446 - mean_squared_error: 0.9446 - val_loss: 0.8499 - val_mean_squared_error: 0.8499
# Epoch 162/200
# 6425094/6425094 [==============================] - 39s 6us/step - loss: 0.9421 - mean_squared_error: 0.9421 - val_loss: 0.8584 - val_mean_squared_error: 0.8584
# Epoch 163/200
# 6425094/6425094 [==============================] - 39s 6us/step - loss: 0.9425 - mean_squared_error: 0.9425 - val_loss: 0.8665 - val_mean_squared_error: 0.8665
# Epoch 164/200
# 6425094/6425094 [==============================] - 39s 6us/step - loss: 0.9420 - mean_squared_error: 0.9420 - val_loss: 0.8544 - val_mean_squared_error: 0.8544
# Epoch 165/200
# 6425094/6425094 [==============================] - 43s 7us/step - loss: 0.9444 - mean_squared_error: 0.9444 - val_loss: 0.8618 - val_mean_squared_error: 0.8618
# Epoch 166/200
# 6425094/6425094 [==============================] - 39s 6us/step - loss: 0.9442 - mean_squared_error: 0.9442 - val_loss: 0.8721 - val_mean_squared_error: 0.8721
# Epoch 167/200
# 6425094/6425094 [==============================] - 39s 6us/step - loss: 0.9419 - mean_squared_error: 0.9419 - val_loss: 0.8554 - val_mean_squared_error: 0.8554
# Epoch 168/200
# 6425094/6425094 [==============================] - 39s 6us/step - loss: 0.9440 - mean_squared_error: 0.9440 - val_loss: 0.8744 - val_mean_squared_error: 0.8744
# Epoch 169/200
# 6425094/6425094 [==============================] - 39s 6us/step - loss: 0.9429 - mean_squared_error: 0.9429 - val_loss: 0.8931 - val_mean_squared_error: 0.8931
# Epoch 170/200
# 6425094/6425094 [==============================] - 40s 6us/step - loss: 0.9470 - mean_squared_error: 0.9470 - val_loss: 0.8532 - val_mean_squared_error: 0.8532
# Epoch 171/200
# 6425094/6425094 [==============================] - 42s 7us/step - loss: 0.9393 - mean_squared_error: 0.9393 - val_loss: 0.8644 - val_mean_squared_error: 0.8644
# Epoch 172/200
# 6425094/6425094 [==============================] - 39s 6us/step - loss: 0.9383 - mean_squared_error: 0.9383 - val_loss: 0.8706 - val_mean_squared_error: 0.8706
# Epoch 173/200
# 6425094/6425094 [==============================] - 39s 6us/step - loss: 0.9542 - mean_squared_error: 0.9542 - val_loss: 0.8675 - val_mean_squared_error: 0.8675
# Epoch 174/200
# 6425094/6425094 [==============================] - 39s 6us/step - loss: 0.9441 - mean_squared_error: 0.9441 - val_loss: 0.8580 - val_mean_squared_error: 0.8580
# Epoch 175/200
# 6425094/6425094 [==============================] - 39s 6us/step - loss: 0.9409 - mean_squared_error: 0.9409 - val_loss: 0.8430 - val_mean_squared_error: 0.8430
# Epoch 176/200
# 6425094/6425094 [==============================] - 39s 6us/step - loss: 0.9566 - mean_squared_error: 0.9566 - val_loss: 0.8604 - val_mean_squared_error: 0.8604
# Epoch 177/200
# 6425094/6425094 [==============================] - 39s 6us/step - loss: 0.9493 - mean_squared_error: 0.9493 - val_loss: 0.8464 - val_mean_squared_error: 0.8464
# Epoch 178/200
# 6425094/6425094 [==============================] - 40s 6us/step - loss: 0.9412 - mean_squared_error: 0.9412 - val_loss: 0.8510 - val_mean_squared_error: 0.8510
# Epoch 179/200
# 6425094/6425094 [==============================] - 39s 6us/step - loss: 0.9417 - mean_squared_error: 0.9417 - val_loss: 0.8641 - val_mean_squared_error: 0.8641
# Epoch 180/200
# 6425094/6425094 [==============================] - 39s 6us/step - loss: 0.9383 - mean_squared_error: 0.9383 - val_loss: 0.8655 - val_mean_squared_error: 0.8655
# Epoch 181/200
# 6425094/6425094 [==============================] - 39s 6us/step - loss: 0.9402 - mean_squared_error: 0.9402 - val_loss: 0.8633 - val_mean_squared_error: 0.8633
# Epoch 182/200
# 6425094/6425094 [==============================] - 39s 6us/step - loss: 0.9431 - mean_squared_error: 0.9431 - val_loss: 0.8646 - val_mean_squared_error: 0.8646
# Epoch 183/200
# 6425094/6425094 [==============================] - 39s 6us/step - loss: 0.9386 - mean_squared_error: 0.9386 - val_loss: 0.8663 - val_mean_squared_error: 0.8663
# Epoch 184/200
# 6425094/6425094 [==============================] - 39s 6us/step - loss: 0.9415 - mean_squared_error: 0.9415 - val_loss: 0.8552 - val_mean_squared_error: 0.8552
# Epoch 185/200
# 6425094/6425094 [==============================] - 39s 6us/step - loss: 0.9387 - mean_squared_error: 0.9387 - val_loss: 0.8690 - val_mean_squared_error: 0.8690
# Epoch 186/200
# 6425094/6425094 [==============================] - 41s 6us/step - loss: 0.9410 - mean_squared_error: 0.9410 - val_loss: 0.8627 - val_mean_squared_error: 0.8627
# Epoch 187/200
# 6425094/6425094 [==============================] - 39s 6us/step - loss: 0.9427 - mean_squared_error: 0.9427 - val_loss: 0.8530 - val_mean_squared_error: 0.8530
# Epoch 188/200
# 6425094/6425094 [==============================] - 39s 6us/step - loss: 0.9401 - mean_squared_error: 0.9401 - val_loss: 0.8563 - val_mean_squared_error: 0.8563
# Epoch 189/200
# 6425094/6425094 [==============================] - 40s 6us/step - loss: 0.9367 - mean_squared_error: 0.9367 - val_loss: 0.8612 - val_mean_squared_error: 0.8612
# Epoch 190/200
# 6425094/6425094 [==============================] - 39s 6us/step - loss: 0.9393 - mean_squared_error: 0.9393 - val_loss: 0.8575 - val_mean_squared_error: 0.8575
# Epoch 191/200
# 6425094/6425094 [==============================] - 39s 6us/step - loss: 0.9480 - mean_squared_error: 0.9480 - val_loss: 0.8501 - val_mean_squared_error: 0.8501
# Epoch 192/200
# 6425094/6425094 [==============================] - 40s 6us/step - loss: 0.9389 - mean_squared_error: 0.9389 - val_loss: 0.8547 - val_mean_squared_error: 0.8547
# Epoch 193/200
# 6425094/6425094 [==============================] - 40s 6us/step - loss: 0.9397 - mean_squared_error: 0.9397 - val_loss: 0.8470 - val_mean_squared_error: 0.8470
# Epoch 194/200
# 6425094/6425094 [==============================] - 39s 6us/step - loss: 0.9400 - mean_squared_error: 0.9400 - val_loss: 0.8633 - val_mean_squared_error: 0.8633
# Epoch 195/200
# 6425094/6425094 [==============================] - 40s 6us/step - loss: 0.9409 - mean_squared_error: 0.9409 - val_loss: 0.8433 - val_mean_squared_error: 0.8433
# Epoch 196/200
# 6425094/6425094 [==============================] - 39s 6us/step - loss: 0.9414 - mean_squared_error: 0.9414 - val_loss: 0.8446 - val_mean_squared_error: 0.8446
# Epoch 197/200
# 6425094/6425094 [==============================] - 39s 6us/step - loss: 0.9487 - mean_squared_error: 0.9487 - val_loss: 0.8547 - val_mean_squared_error: 0.8547
# Epoch 198/200
# 6425094/6425094 [==============================] - 40s 6us/step - loss: 0.9476 - mean_squared_error: 0.9476 - val_loss: 0.8650 - val_mean_squared_error: 0.8650
# Epoch 199/200
# 6425094/6425094 [==============================] - 40s 6us/step - loss: 0.9416 - mean_squared_error: 0.9416 - val_loss: 0.8863 - val_mean_squared_error: 0.8863
# Epoch 200/200
# 6425094/6425094 [==============================] - 39s 6us/step - loss: 0.9410 - mean_squared_error: 0.9410 - val_loss: 0.8849 - val_mean_squared_error: 0.8849
# 7913.958300352097

# %%
print('-Model predict')

Y_test = model.predict(X_test).clip(0, 20)
y_pred = np.reshape((Y_test), Y_test.shape[0],1)

submissionLSTM = pd.DataFrame({
    "ID": test.index, 
    "item_cnt_month": y_pred
})
# Out:
# -Model predict

# %% [markdown]
# Combine xgboost and lstm model

# %%
submission['item_cnt_month'] = (submission['item_cnt_month'] + submissionLSTM['item_cnt_month'])/2

print('-Save predict')
submission.to_csv('XGBOOST_LSTM_submission.csv', index=False)
print('output file :','XGBOOST_LSTM_submission','saved')
# Out:
# -Save predict
# output file : XGBOOST_LSTM_submission saved

# %%
# save the model to disk
filename = 'NeuralModelSafe.sav'
pickle.dump(model, open(filename, 'wb'))

# %%
# load the model from disk
#loaded_model = pickle.load(open(filename, 'rb'))

# %%
Y_test
# Out:
# array([[0.47726047],
#        [0.47726047],
#        [0.47726047],
#        ...,
#        [0.12980938],
#        [0.12980938],
#        [0.12980938]], dtype=float32)
